# %% [markdown]
# ## IMDB Cleaning (Trase, Mark, Karl Durant)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sqlite3
import numpy as np
tips = sns.load_dataset('tips')
sns.set_theme(style="whitegrid")
# %matplotlib inline

# %%
conn = sqlite3.connect('../../zippedData/im (2).db')

# %%
pd.read_sql("""
SELECT *
FROM movie_basics

""", conn)
# Out:
#          movie_id                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# 2                        The Other Side of the Wind        2018
# 3                                   Sabse Bada Sukh        2018
# 4                             La Telenovela Errante        2017
# ...                                             ...         ...
# 146139                          Kuambil Lagi Hatiku        2019
# 146140  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141                              Dankyavar Danka        2013
# 146142                                       6 Gunn        2017
# 146143               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes                genres
# 0                 175.0    Action,Crime,Drama
# 1                 114.0       Biography,Drama
# 2                 122.0                 Drama
# 3                   NaN          Comedy,Drama
# 4                  80.0  Comedy,Drama,Fantasy
# ...                 ...                   ...
# 146139            123.0                 Drama
# 146140              NaN           Documentary
# 146141              NaN                Comedy
# 146142            116.0                  None
# 146143              NaN           Documentary
#
# [146144 rows x 6 columns]

# %%
pd.read_sql("""
SELECT MOVIE_ID AS Movie_ID, AVERAGERATING AS Avg_Rating, NUMVOTES AS Number_of_Votes, PRIMARY_TITLE AS Title, START_YEAR AS Year, RUNTIME_MINUTES AS Minutes, GENRES AS Genres
FROM MOVIE_RATINGS
JOIN MOVIE_BASICS
    USING(MOVIE_ID)
WHERE NUMVOTES > 15000
ORDER BY NUMVOTES DESC
;
""", conn).head()
# Out:
#     Movie_ID  Avg_Rating  Number_of_Votes                  Title  Year  \
# 0  tt1375666         8.8          1841066              Inception  2010
# 1  tt1345836         8.4          1387769  The Dark Knight Rises  2012
# 2  tt0816692         8.6          1299334           Interstellar  2014
# 3  tt1853728         8.4          1211405       Django Unchained  2012
# 4  tt0848228         8.1          1183655           The Avengers  2012
#
#    Minutes                   Genres
# 0    148.0  Action,Adventure,Sci-Fi
# 1    164.0          Action,Thriller
# 2    169.0   Adventure,Drama,Sci-Fi
# 3    165.0            Drama,Western
# 4    143.0  Action,Adventure,Sci-Fi

# %%
pd.read_sql("""
SELECT MOVIE_ID AS Movie_ID, AVERAGERATING AS Avg_Rating, NUMVOTES AS Number_of_Votes, PERSON_ID AS Person_ID, CATEGORY AS Profession
FROM MOVIE_RATINGS
JOIN PRINCIPALS
    USING(MOVIE_ID)
WHERE NUMVOTES > 15000
ORDER BY NUMVOTES DESC
;
""", conn)
# Out:
#         Movie_ID  Avg_Rating  Number_of_Votes  Person_ID           Profession
# 0      tt1375666         8.8          1841066  nm0000138                actor
# 1      tt1375666         8.8          1841066  nm0001877             composer
# 2      tt1375666         8.8          1841066  nm0002892      cinematographer
# 3      tt1375666         8.8          1841066  nm0245596  production_designer
# 4      tt1375666         8.8          1841066  nm0330687                actor
# ...          ...         ...              ...        ...                  ...
# 21491  tt1434435         6.3            15012  nm0500329               writer
# 21492  tt1434435         6.3            15012  nm0711840             producer
# 21493  tt1434435         6.3            15012  nm0764552             producer
# 21494  tt1434435         6.3            15012  nm1135423             director
# 21495  tt1434435         6.3            15012  nm1556126               writer
#
# [21496 rows x 5 columns]

# %%
pd.read_sql("""
SELECT MOVIE_ID AS Movie_ID, PERSON_ID AS Person_ID, CATEGORY AS Profession, PRIMARY_NAME AS Name
FROM PERSONS
JOIN PRINCIPALS
    USING(PERSON_ID)
;
""", conn)
# Out:
#           Movie_ID  Person_ID Profession                 Name
# 0        tt2398241  nm0061671   producer    Mary Ellen Bauder
# 1        tt0433397  nm0061865   composer         Joseph Bauer
# 2        tt1681372  nm0061865   composer         Joseph Bauer
# 3        tt2281215  nm0061865   composer         Joseph Bauer
# 4        tt2387710  nm0061865   composer         Joseph Bauer
# ...            ...        ...        ...                  ...
# 1027907  tt6527982  nm9990381    actress         Susan Grobes
# 1027908  tt8737130  nm9990690    actress          Joo Yeon So
# 1027909  tt8734436  nm9991320    actress       Madeline Smith
# 1027910  tt8739240  nm9991786   producer  Michelle Modigliani
# 1027911  tt8743182  nm9993380   director       Pegasus Envoyé
#
# [1027912 rows x 4 columns]

# %%
imdb_important_data = pd.read_sql("""
SELECT Distinct primary_title as Title, averagerating as IMDB_Rating, runtime_minutes as Runtime, start_year as Year, genres as Genres
FROM MOVIE_RATINGS
JOIN MOVIE_BASICS
    USING(MOVIE_ID)
JOIN MOVIE_AKAS
    USING(MOVIE_ID)
WHERE numvotes > 5000 and region == "US"
ORDER BY averagerating DESC
;
""", conn)

# %%
imdb_important_data
# Out:
#                                   Title  IMDB_Rating  Runtime  Year  \
# 0     Once Upon a Time ... in Hollywood          9.7    159.0  2019
# 1                               Peranbu          9.4    147.0  2018
# 2                                Wheels          9.3    115.0  2014
# 3                 O.J.: Made in America          8.9    467.0  2016
# 4                             Inception          8.8    148.0  2010
# ...                                 ...          ...      ...   ...
# 2764                         Himmatwala          1.7    150.0  2013
# 2765     Justin Bieber: Never Say Never          1.6    105.0  2011
# 2766                  Code Name: K.O.Z.          1.5    114.0  2015
# 2767                   Saving Christmas          1.5     79.0  2014
# 2768                       Potato Salad          1.3     81.0  2015
#
#                            Genres
# 0                    Comedy,Drama
# 1                           Drama
# 2                           Drama
# 3     Biography,Crime,Documentary
# 4         Action,Adventure,Sci-Fi
# ...                           ...
# 2764          Action,Comedy,Drama
# 2765            Documentary,Music
# 2766                Crime,Mystery
# 2767                Comedy,Family
# 2768                Comedy,Horror
#
# [2769 rows x 5 columns]

# %%
imdb_clean_table = pd.read_sql("""
SELECT DISTINCT PRIMARY_TITLE AS Title, AVERAGERATING AS Rating, START_YEAR AS Year, RUNTIME_MINUTES AS Runtime, GENRES AS Genres
FROM MOVIE_RATINGS
JOIN MOVIE_BASICS
    USING(MOVIE_ID)
JOIN MOVIE_AKAS
    USING(MOVIE_ID)
WHERE numvotes > 5000
ORDER BY averagerating DESC
;
""", conn)

imdb_clean_table
# Out:
#                                   Title  Rating  Year  Runtime  \
# 0     Once Upon a Time ... in Hollywood     9.7  2019    159.0
# 1                         Aloko Udapadi     9.5  2017    113.0
# 2                               Peranbu     9.4  2018    147.0
# 3                       The Mountain II     9.3  2016    135.0
# 4                              Aynabaji     9.3  2016    147.0
# ...                                 ...     ...   ...      ...
# 3913                   Saving Christmas     1.5  2014     79.0
# 3914                  Code Name: K.O.Z.     1.5  2015    114.0
# 3915                           Smolensk     1.4  2016    120.0
# 3916                       Potato Salad     1.3  2015     81.0
# 3917     Cumali Ceber: Allah Seni Alsin     1.3  2017    100.0
#
#                       Genres
# 0               Comedy,Drama
# 1              Drama,History
# 2                      Drama
# 3           Action,Drama,War
# 4     Crime,Mystery,Thriller
# ...                      ...
# 3913           Comedy,Family
# 3914           Crime,Mystery
# 3915          Drama,Thriller
# 3916           Comedy,Horror
# 3917                  Comedy
#
# [3918 rows x 5 columns]

# %% [markdown]
# ## TMDB x Movie Gross (Trase, Karl, and Mark)

# %%
movie_gross_df = pd.read_csv('../../zippedData/bom.movie_gross.csv.gz')

# %%
tmdb_df = pd.read_csv('../../zippedData/tmdb.movies.csv.gz')

# %%
movie_budgets_df = pd.read_csv('../../zippedData/tn.movie_budgets.csv.gz')

# %%
movie_budgets_df['production_budget'] = movie_budgets_df['production_budget'].str.replace(',', '').str.replace('$', '').astype('float')
movie_budgets_df['domestic_gross'] = movie_budgets_df['domestic_gross'].str.replace(',', '').str.replace('$', '').astype('float')
movie_budgets_df['worldwide_gross'] = movie_budgets_df['worldwide_gross'].str.replace(',', '').str.replace('$', '').astype('float')

# %%
# Calculate the profit and add it as a new column to the movie budgets dataframe
movie_budgets_df['profit'] = movie_budgets_df['worldwide_gross'] - movie_budgets_df['production_budget']

# Sort the dataframe by the profit column in descending order to see the most successful movies
most_profitable_movies = movie_budgets_df.sort_values('profit', ascending=False)

# %%
merged_df = movie_gross_df.merge(movie_budgets_df, how='right', left_on='title', right_on='movie')

# %%
merged_tmdb_budget = movie_budgets_df.merge(tmdb_df, how='inner', left_on='movie', right_on='title')

# %%
new_merged = merged_tmdb_budget.drop(['original_title'], axis=1)

# %%
karl_carolyn_merge = new_merged.drop(['id_x','release_date_x','genre_ids','id_y','Unnamed: 0'], axis=1)

# %%
# Creating Quarter Column
karl_carolyn_merge['release_date_y'] = pd.to_datetime(karl_carolyn_merge['release_date_y'])

karl_carolyn_merge['Quarter'] = karl_carolyn_merge['release_date_y'].dt.to_period('Q')

# %%
karl_carolyn_merge.rename(columns = {'movie':'Title'},inplace = True)

# %%
karl_carolyn_merge.rename(columns = {'profit':'Profit'},inplace = True)

# %%
karl_carolyn_merge.rename(columns = {'release_date_y':'Release_Date'},inplace = True)

# %%
karl_carolyn_merge.rename(columns = {'production_budget':'Production_Budget'},inplace = True)

# %%
karl_carolyn_merge.rename(columns = {'domestic_gross':'Domestic_Gross'},inplace = True)

# %%
karl_carolyn_merge.rename(columns = {'worldwide_gross':'Worldwide_Gross'},inplace = True)

# %%
karl_carolyn_merge.rename(columns = {'original_language':'Original_Language'},inplace = True)

# %%
karl_carolyn_merge.rename(columns = {'popularity':'Popularity'},inplace = True)

# %%
karl_carolyn_merge.rename(columns = {'vote_average':'TMDB_Rating'},inplace = True)

# %%
karl_carolyn_merge.rename(columns = {'vote_count':'Vote_Count'},inplace = True)

# %%
karl_carolyn_merge = karl_carolyn_merge.drop(['title'], axis=1)
karl_carolyn_merge
# Out:
#                                             Title  Production_Budget  \
# 0                                          Avatar        425000000.0
# 1     Pirates of the Caribbean: On Stranger Tides        410600000.0
# 2                         Avengers: Age of Ultron        330600000.0
# 3                          Avengers: Infinity War        300000000.0
# 4                                  Justice League        300000000.0
# ...                                           ...                ...
# 2380                                       Exeter            25000.0
# 2381                                          Ten            25000.0
# 2382                                    Dry Spell            22000.0
# 2383                     All Superheroes Must Die            20000.0
# 2384                                    Newlyweds             9000.0
#
#       Domestic_Gross  Worldwide_Gross        Profit Original_Language  \
# 0        760507625.0     2.776345e+09  2.351345e+09                en
# 1        241063875.0     1.045664e+09  6.350639e+08                en
# 2        459005868.0     1.403014e+09  1.072414e+09                en
# 3        678815482.0     2.048134e+09  1.748134e+09                en
# 4        229024295.0     6.559452e+08  3.559452e+08                en
# ...              ...              ...           ...               ...
# 2380             0.0     4.897920e+05  4.647920e+05                en
# 2381             0.0     0.000000e+00 -2.500000e+04                en
# 2382             0.0     0.000000e+00 -2.200000e+04                en
# 2383             0.0     0.000000e+00 -2.000000e+04                en
# 2384          4584.0     4.584000e+03 -4.416000e+03                en
#
#       Popularity Release_Date  TMDB_Rating  Vote_Count Quarter
# 0         26.526   2009-12-18          7.4       18676  2009Q4
# 1         30.579   2011-05-20          6.4        8571  2011Q2
# 2         44.383   2015-05-01          7.3       13457  2015Q2
# 3         80.773   2018-04-27          8.3       13948  2018Q2
# 4         34.953   2017-11-17          6.2        7510  2017Q4
# ...          ...          ...          ...         ...     ...
# 2380       5.934   2015-03-26          4.7         121  2015Q1
# 2381       1.575   2014-03-28          5.4           5  2014Q1
# 2382       0.600   2013-02-14          6.0           1  2013Q1
# 2383       2.078   2013-01-04          3.9          19  2013Q1
# 2384       1.973   2011-12-26          5.4           7  2011Q4
#
# [2385 rows x 11 columns]

# %% [markdown]
# ## Quarter Column & Cleaning (Trase, Karl, Mark, Al Ameen, Carolyn)

# %%
# Created new column with Quarter column values as a string
karl_carolyn_merge['Q'] = karl_carolyn_merge['Quarter'].astype(str)
karl_carolyn_merge['Q']
# Out:
# 0       2009Q4
# 1       2011Q2
# 2       2015Q2
# 3       2018Q2
# 4       2017Q4
#          ...
# 2380    2015Q1
# 2381    2014Q1
# 2382    2013Q1
# 2383    2013Q1
# 2384    2011Q4
# Name: Q, Length: 2385, dtype: object

# %%
# Creating a quarter of year column
karl_carolyn_merge['s'] = karl_carolyn_merge['Q'].map( lambda x: x[-1:])
karl_carolyn_merge['s']
# Out:
# 0       4
# 1       2
# 2       2
# 3       2
# 4       4
#        ..
# 2380    1
# 2381    1
# 2382    1
# 2383    1
# 2384    4
# Name: s, Length: 2385, dtype: object

# %%
karl_carolyn_merge['Vote_Count'].unique
# Out:
# <bound method Series.unique of 0       18676
# 1        8571
# 2       13457
# 3       13948
# 4        7510
#         ...
# 2380      121
# 2381        5
# 2382        1
# 2383       19
# 2384        7
# Name: Vote_Count, Length: 2385, dtype: int64>

# %%
karl_carolyn_merge2 = karl_carolyn_merge

# %%
# Drops rows with less than 5 votes for ratings
karl_carolyn_merge2.drop(karl_carolyn_merge2[karl_carolyn_merge2.Vote_Count < 5].index, inplace=True)

# %%
#karl_carolyn_merge2 = karl_carolyn_merge2.drop(['Quarter'], axis=1)
karl_carolyn_merge2
# Out:
#                                             Title  Production_Budget  \
# 0                                          Avatar        425000000.0
# 1     Pirates of the Caribbean: On Stranger Tides        410600000.0
# 2                         Avengers: Age of Ultron        330600000.0
# 3                          Avengers: Infinity War        300000000.0
# 4                                  Justice League        300000000.0
# ...                                           ...                ...
# 2378                                       Krisha            30000.0
# 2380                                       Exeter            25000.0
# 2381                                          Ten            25000.0
# 2383                     All Superheroes Must Die            20000.0
# 2384                                    Newlyweds             9000.0
#
#       Domestic_Gross  Worldwide_Gross        Profit Original_Language  \
# 0        760507625.0     2.776345e+09  2.351345e+09                en
# 1        241063875.0     1.045664e+09  6.350639e+08                en
# 2        459005868.0     1.403014e+09  1.072414e+09                en
# 3        678815482.0     2.048134e+09  1.748134e+09                en
# 4        229024295.0     6.559452e+08  3.559452e+08                en
# ...              ...              ...           ...               ...
# 2378        144822.0     1.448220e+05  1.148220e+05                en
# 2380             0.0     4.897920e+05  4.647920e+05                en
# 2381             0.0     0.000000e+00 -2.500000e+04                en
# 2383             0.0     0.000000e+00 -2.000000e+04                en
# 2384          4584.0     4.584000e+03 -4.416000e+03                en
#
#       Popularity Release_Date  TMDB_Rating  Vote_Count Quarter       Q  s
# 0         26.526   2009-12-18          7.4       18676  2009Q4  2009Q4  4
# 1         30.579   2011-05-20          6.4        8571  2011Q2  2011Q2  2
# 2         44.383   2015-05-01          7.3       13457  2015Q2  2015Q2  2
# 3         80.773   2018-04-27          8.3       13948  2018Q2  2018Q2  2
# 4         34.953   2017-11-17          6.2        7510  2017Q4  2017Q4  4
# ...          ...          ...          ...         ...     ...     ... ..
# 2378       5.288   2016-03-18          6.8          86  2016Q1  2016Q1  1
# 2380       5.934   2015-03-26          4.7         121  2015Q1  2015Q1  1
# 2381       1.575   2014-03-28          5.4           5  2014Q1  2014Q1  1
# 2383       2.078   2013-01-04          3.9          19  2013Q1  2013Q1  1
# 2384       1.973   2011-12-26          5.4           7  2011Q4  2011Q4  4
#
# [2094 rows x 13 columns]

# %%
# Renaming Column
karl_carolyn_merge2.rename(columns = {'s':'Quarter_Num'},inplace = True)

# %%
#Creating Year Column
karl_carolyn_merge2['Year'] = karl_carolyn_merge2['Q'].map( lambda x: x[:4])

# %%
# Dropping Column Q
karl_carolyn_merge2 = karl_carolyn_merge2.drop(['Q'], axis=1)

# %%
karl_carolyn_merge2 = karl_carolyn_merge2.drop(['Quarter'], axis=1)

# %%
# Dropping Release Date
karl_carolyn_merge2 = karl_carolyn_merge2.drop(['Release_Date'], axis=1)
karl_carolyn_merge2
# Out:
#                                             Title  Production_Budget  \
# 0                                          Avatar        425000000.0
# 1     Pirates of the Caribbean: On Stranger Tides        410600000.0
# 2                         Avengers: Age of Ultron        330600000.0
# 3                          Avengers: Infinity War        300000000.0
# 4                                  Justice League        300000000.0
# ...                                           ...                ...
# 2378                                       Krisha            30000.0
# 2380                                       Exeter            25000.0
# 2381                                          Ten            25000.0
# 2383                     All Superheroes Must Die            20000.0
# 2384                                    Newlyweds             9000.0
#
#       Domestic_Gross  Worldwide_Gross        Profit Original_Language  \
# 0        760507625.0     2.776345e+09  2.351345e+09                en
# 1        241063875.0     1.045664e+09  6.350639e+08                en
# 2        459005868.0     1.403014e+09  1.072414e+09                en
# 3        678815482.0     2.048134e+09  1.748134e+09                en
# 4        229024295.0     6.559452e+08  3.559452e+08                en
# ...              ...              ...           ...               ...
# 2378        144822.0     1.448220e+05  1.148220e+05                en
# 2380             0.0     4.897920e+05  4.647920e+05                en
# 2381             0.0     0.000000e+00 -2.500000e+04                en
# 2383             0.0     0.000000e+00 -2.000000e+04                en
# 2384          4584.0     4.584000e+03 -4.416000e+03                en
#
#       Popularity  TMDB_Rating  Vote_Count Quarter_Num  Year
# 0         26.526          7.4       18676           4  2009
# 1         30.579          6.4        8571           2  2011
# 2         44.383          7.3       13457           2  2015
# 3         80.773          8.3       13948           2  2018
# 4         34.953          6.2        7510           4  2017
# ...          ...          ...         ...         ...   ...
# 2378       5.288          6.8          86           1  2016
# 2380       5.934          4.7         121           1  2015
# 2381       1.575          5.4           5           1  2014
# 2383       2.078          3.9          19           1  2013
# 2384       1.973          5.4           7           4  2011
#
# [2094 rows x 11 columns]

# %% [markdown]
# ## Final Dataset (Trase)

# %%
# Merging karl_carolyn_merge2 with imdb_clean_table

final_dataset = karl_carolyn_merge2.merge(imdb_clean_table, how='left', left_on='Title', right_on='Title')
final_dataset
# Out:
#                                             Title  Production_Budget  \
# 0                                          Avatar        425000000.0
# 1     Pirates of the Caribbean: On Stranger Tides        410600000.0
# 2                         Avengers: Age of Ultron        330600000.0
# 3                          Avengers: Infinity War        300000000.0
# 4                                  Justice League        300000000.0
# ...                                           ...                ...
# 2120                                       Krisha            30000.0
# 2121                                       Exeter            25000.0
# 2122                                          Ten            25000.0
# 2123                     All Superheroes Must Die            20000.0
# 2124                                    Newlyweds             9000.0
#
#       Domestic_Gross  Worldwide_Gross        Profit Original_Language  \
# 0        760507625.0     2.776345e+09  2.351345e+09                en
# 1        241063875.0     1.045664e+09  6.350639e+08                en
# 2        459005868.0     1.403014e+09  1.072414e+09                en
# 3        678815482.0     2.048134e+09  1.748134e+09                en
# 4        229024295.0     6.559452e+08  3.559452e+08                en
# ...              ...              ...           ...               ...
# 2120        144822.0     1.448220e+05  1.148220e+05                en
# 2121             0.0     4.897920e+05  4.647920e+05                en
# 2122             0.0     0.000000e+00 -2.500000e+04                en
# 2123             0.0     0.000000e+00 -2.000000e+04                en
# 2124          4584.0     4.584000e+03 -4.416000e+03                en
#
#       Popularity  TMDB_Rating  Vote_Count Quarter_Num Year_x  Rating  Year_y  \
# 0         26.526          7.4       18676           4   2009     NaN     NaN
# 1         30.579          6.4        8571           2   2011     6.6  2011.0
# 2         44.383          7.3       13457           2   2015     7.3  2015.0
# 3         80.773          8.3       13948           2   2018     8.5  2018.0
# 4         34.953          6.2        7510           4   2017     6.5  2017.0
# ...          ...          ...         ...         ...    ...     ...     ...
# 2120       5.288          6.8          86           1   2016     7.2  2015.0
# 2121       5.934          4.7         121           1   2015     4.5  2015.0
# 2122       1.575          5.4           5           1   2014     NaN     NaN
# 2123       2.078          3.9          19           1   2013     NaN     NaN
# 2124       1.973          5.4           7           4   2011     NaN     NaN
#
#       Runtime                    Genres
# 0         NaN                       NaN
# 1       136.0  Action,Adventure,Fantasy
# 2       141.0   Action,Adventure,Sci-Fi
# 3       149.0   Action,Adventure,Sci-Fi
# 4       120.0  Action,Adventure,Fantasy
# ...       ...                       ...
# 2120     83.0                     Drama
# 2121     91.0   Horror,Mystery,Thriller
# 2122      NaN                       NaN
# 2123      NaN                       NaN
# 2124      NaN                       NaN
#
# [2125 rows x 15 columns]

# %%
final_dataset['Runtime'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         NaN
# 1       136.0
# 2       141.0
# 3       149.0
# 4       120.0
#         ...
# 2120     83.0
# 2121     91.0
# 2122      NaN
# 2123      NaN
# 2124      NaN
# Name: Runtime, Length: 2125, dtype: float64>

# %%
final_dataset['Rating'].isnull().sum()
# Out:
# 405

# %%
#final_dataset['Genres'].astype(str)

# %%
final_dataset2 = final_dataset.dropna(how="any",axis = 0)
final_dataset2
# Out:
#                                             Title  Production_Budget  \
# 1     Pirates of the Caribbean: On Stranger Tides        410600000.0
# 2                         Avengers: Age of Ultron        330600000.0
# 3                          Avengers: Infinity War        300000000.0
# 4                                  Justice League        300000000.0
# 5                                  Justice League        300000000.0
# ...                                           ...                ...
# 2114                                  The Dirties            55000.0
# 2115                               Tiny Furniture            50000.0
# 2119                                       Krisha            30000.0
# 2120                                       Krisha            30000.0
# 2121                                       Exeter            25000.0
#
#       Domestic_Gross  Worldwide_Gross        Profit Original_Language  \
# 1        241063875.0     1.045664e+09  6.350639e+08                en
# 2        459005868.0     1.403014e+09  1.072414e+09                en
# 3        678815482.0     2.048134e+09  1.748134e+09                en
# 4        229024295.0     6.559452e+08  3.559452e+08                en
# 5        229024295.0     6.559452e+08  3.559452e+08                en
# ...              ...              ...           ...               ...
# 2114             0.0     0.000000e+00 -5.500000e+04                en
# 2115        391674.0     4.241490e+05  3.741490e+05                en
# 2119        144822.0     1.448220e+05  1.148220e+05                en
# 2120        144822.0     1.448220e+05  1.148220e+05                en
# 2121             0.0     4.897920e+05  4.647920e+05                en
#
#       Popularity  TMDB_Rating  Vote_Count Quarter_Num Year_x  Rating  Year_y  \
# 1         30.579          6.4        8571           2   2011     6.6  2011.0
# 2         44.383          7.3       13457           2   2015     7.3  2015.0
# 3         80.773          8.3       13948           2   2018     8.5  2018.0
# 4         34.953          6.2        7510           4   2017     6.5  2017.0
# 5         34.953          6.2        7510           4   2017     6.5  2017.0
# ...          ...          ...         ...         ...    ...     ...     ...
# 2114       2.971          6.1          57           4   2013     6.8  2013.0
# 2115       6.695          5.9          82           4   2010     6.2  2010.0
# 2119       5.288          6.8          86           1   2016     7.2  2015.0
# 2120       5.288          6.8          86           1   2016     7.2  2015.0
# 2121       5.934          4.7         121           1   2015     4.5  2015.0
#
#       Runtime                    Genres
# 1       136.0  Action,Adventure,Fantasy
# 2       141.0   Action,Adventure,Sci-Fi
# 3       149.0   Action,Adventure,Sci-Fi
# 4       120.0  Action,Adventure,Fantasy
# 5       120.0  Action,Adventure,Fantasy
# ...       ...                       ...
# 2114     83.0               Crime,Drama
# 2115     98.0      Comedy,Drama,Romance
# 2119     83.0                     Drama
# 2120     83.0                     Drama
# 2121     91.0   Horror,Mystery,Thriller
#
# [1720 rows x 15 columns]

# %%
final_dataset2['Genres'].str.split(",").map(lambda x: x[0])
# Out:
# 1       Action
# 2       Action
# 3       Action
# 4       Action
# 5       Action
#          ...
# 2114     Crime
# 2115    Comedy
# 2119     Drama
# 2120     Drama
# 2121    Horror
# Name: Genres, Length: 1720, dtype: object

# %%
final_dataset2['Genres'].unique()
# Out:
# array(['Action,Adventure,Fantasy', 'Action,Adventure,Sci-Fi',
#        'Action,Adventure,Thriller', 'Action,Thriller',
#        'Action,Adventure,Western', 'Adventure,Animation,Comedy',
#        'Adventure,Family,Fantasy', 'Adventure,Fantasy',
#        'Action,Crime,Thriller', 'Action,Adventure,Comedy',
#        'Action,Adventure,Drama', 'Action,Adventure,Animation',
#        'Action,Adventure,Horror', 'Drama,Romance', 'Drama,Mystery,Sci-Fi',
#        'Action,Adventure,Family', 'Adventure,Drama,Family',
#        'Action,Horror,Sci-Fi', 'Action,Sci-Fi', 'Adventure,Drama,Sci-Fi',
#        'Family,Fantasy,Musical', 'Drama,Fantasy,Romance',
#        'Action,Drama,History', 'Adventure,Drama,Sport',
#        'Comedy,Fantasy,Horror', 'Action,Drama,Thriller',
#        'Drama,Fantasy,Horror', 'Adventure,Comedy,Family',
#        'Adventure,Animation,Family', 'Adventure,Animation,Drama',
#        'Action,Comedy,Fantasy', 'Action,Adventure,Biography',
#        'Comedy,Family,Fantasy', 'Action,Animation,Comedy',
#        'Action,Mystery,Thriller', 'Action,Drama,Sci-Fi',
#        'Action,Adventure,Crime', 'Adventure,Mystery,Sci-Fi',
#        'Action,Adventure,Mystery', 'Adventure,Drama,Fantasy',
#        'Action,Crime,Sci-Fi', 'Action,Sci-Fi,Thriller',
#        'Drama,Sci-Fi,Thriller', 'Action,Fantasy,War',
#        'Drama,Romance,Sci-Fi', 'Action,Comedy,Crime',
#        'Action,Drama,Family', 'Action,Drama,Romance',
#        'Action,Drama,Mystery', 'Drama,Western', 'Comedy,Romance',
#        'Biography,Crime,Drama', 'Action,Crime,Sport',
#        'Horror,Sci-Fi,Thriller', 'Drama,Family,Fantasy',
#        'Comedy,Drama,Romance', 'Comedy', 'Adventure,Comedy,Drama',
#        'Crime,Drama,Mystery', 'Action,Comedy,Sci-Fi',
#        'Action,Adventure,Romance', 'Drama,History',
#        'Action,Crime,Fantasy', 'Animation,Comedy,Family',
#        'Action,Comedy,Family', 'Biography,Drama,Musical',
#        'Comedy,Mystery', 'Mystery,Thriller', 'Action,Drama,War',
#        'Comedy,Family,Romance', 'Crime,Mystery,Thriller',
#        'Action,Drama,Fantasy', 'Biography,Drama', 'Action,Comedy,Romance',
#        'Drama,History,War', 'Comedy,Drama,History', 'Comedy,Drama',
#        'Comedy,Drama,Musical', 'Action,Crime,Mystery', 'Drama,Sci-Fi',
#        'Action,Fantasy,Horror', 'Biography,Drama,History',
#        'Biography,Drama,Sport', 'Adventure,Comedy', 'Comedy,Drama,Family',
#        'Comedy,Crime,Drama', 'Crime,Thriller', 'Action,Crime,Drama',
#        'Drama,Mystery,Thriller', 'Drama', 'Biography,Comedy,Drama',
#        'Drama,Sport', 'Comedy,Western', 'Action,Biography,Drama',
#        'Action,Fantasy,Thriller', 'Biography,Drama,Music',
#        'Biography,Drama,Thriller', 'Drama,Romance,Thriller',
#        'Comedy,Crime,Romance', 'Adventure,Comedy,Crime',
#        'Drama,Music,Musical', 'Action,Comedy,Horror',
#        'Adventure,Drama,Horror', 'Drama,Thriller', 'Comedy,Fantasy',
#        'Romance,Sci-Fi,Thriller', 'Mystery,Sci-Fi,Thriller',
#        'Crime,Drama,Thriller', 'Action,Biography,Comedy', 'Crime,Drama',
#        'Comedy,Family', 'Adventure,Comedy,Fantasy', 'Crime,Drama,History',
#        'Adventure,Drama,History', 'Comedy,Music',
#        'Animation,Drama,Fantasy', 'Action,Comedy,Sport',
#        'Fantasy,Horror,Mystery', 'Action,Fantasy,Western', 'Comedy,Crime',
#        'Drama,History,Thriller', 'Adventure,Comedy,Music', 'Horror',
#        'Horror,Mystery', 'Adventure,Comedy,Sci-Fi', 'Comedy,Drama,Sport',
#        'Biography,Drama,Family', 'Drama,Horror,Sci-Fi',
#        'Horror,Mystery,Sci-Fi', 'Drama,Family', 'Drama,Horror,Mystery',
#        'Comedy,Sci-Fi', 'Adventure,Biography,Drama', 'Horror,Thriller',
#        'Adventure,Drama,Western', 'Crime,Drama,Horror', 'Drama,Fantasy',
#        'Comedy,Romance,Sport', 'Action,Mystery,Sci-Fi',
#        'Adventure,Comedy,Romance', 'Drama,Music,Romance',
#        'Comedy,Horror,Sci-Fi', 'Comedy,Horror,Romance',
#        'Comedy,Fantasy,Romance', 'Comedy,Crime,Thriller', 'Drama,Horror',
#        'Horror,Mystery,Thriller', 'Adventure,Drama,Thriller',
#        'Action,Drama', 'Comedy,Horror', 'Adventure,Drama,Romance',
#        'Action,Biography,Crime', 'Biography,Drama,Romance',
#        'Action,Comedy', 'Action,Crime', 'Comedy,Drama,Music',
#        'Drama,Romance,War', 'Fantasy,Horror,Thriller', 'Fantasy',
#        'Drama,History,Romance', 'Action,Drama,Western',
#        'Comedy,Music,Romance', 'Action,Comedy,Documentary',
#        'Biography,Drama,War', 'Drama,Music', 'Comedy,Drama,Fantasy',
#        'Crime,Horror,Mystery', 'Drama,War', 'Comedy,Sport',
#        'Animation,Drama', 'Drama,Family,Sport', 'Action',
#        'Comedy,Music,War', 'Drama,Horror,Thriller',
#        'Comedy,Mystery,Sci-Fi', 'Action,Adventure', 'Documentary,Music',
#        'Adventure,Family,Sci-Fi', 'Drama,Thriller,War',
#        'Action,Comedy,Drama', 'Biography,Comedy,Crime',
#        'Comedy,Drama,Mystery', 'Adventure,Crime,Drama',
#        'Drama,Fantasy,Music', 'Adventure,Horror,Sci-Fi',
#        'Comedy,Documentary', 'Action,Horror,Thriller',
#        'Drama,History,Mystery', 'Comedy,Horror,Mystery',
#        'Adventure,Biography,Comedy', 'Animation,Comedy,Drama',
#        'Adventure,Drama', 'Drama,Mystery,War', 'Drama,Mystery,Romance',
#        'Documentary,Sport,Thriller', 'Adventure,Horror,Mystery',
#        'Drama,Fantasy,Mystery', 'Documentary', 'Horror,Music,Thriller',
#        'Crime,Drama,Romance', 'Action,Crime,Horror',
#        'Adventure,Crime,Thriller', 'Biography,Drama,Fantasy',
#        'Comedy,Fantasy,Sci-Fi', 'Comedy,Drama,Horror',
#        'Drama,Thriller,Western', 'Drama,Mystery', 'Crime,Documentary',
#        'Documentary,Drama,History', 'Documentary,History,War',
#        'Adventure,Horror', 'Comedy,Fantasy,Thriller', 'Documentary,Drama'],
#       dtype=object)

# %%
# Pulling the primary genre and creating new column with primary genre
final_dataset2['Genre1']=final_dataset2['Genres'].str.split(",").map(lambda x: x[0])
# Out:
# <ipython-input-49-ad845335369c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_dataset2['Genre1']=final_dataset2['Genres'].str.split(",").map(lambda x: x[0])

# %%
# Dropping duplicates Movies
final_dataset2 = final_dataset2.drop_duplicates(subset = ['Title'])

# %%
# Barplot for Genre by Avg Profit
sns.barplot(x = 'Profit', y='Genre1',data = final_dataset2)
# Out:
# <AxesSubplot:xlabel='Profit', ylabel='Genre1'>

# %%
#final_dataset["Genres"] = final_dataset["Genres"].str.split(",").apply(lambda x: [i.strip() for i in x])
#final_dataset
#final_dataset2['Genre'] = final_dataset2['Genres'].map( lambda x: x[:4])
#final_dataset2

#dfmi.loc[:, ('one', 'second')]

# %%
final_dataset2.rename(columns = {'Rating':'IMDB_Rating'},inplace = True)
# Out:
# C:\Users\tjester\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
final_dataset2 = final_dataset2.drop(['Year_y'], axis=1)

# %%
final_dataset2
# Out:
#                                             Title  Production_Budget  \
# 1     Pirates of the Caribbean: On Stranger Tides        410600000.0
# 2                         Avengers: Age of Ultron        330600000.0
# 3                          Avengers: Infinity War        300000000.0
# 4                                  Justice League        300000000.0
# 6                                         Spectre        300000000.0
# ...                                           ...                ...
# 2110                                     Absentia            70000.0
# 2114                                  The Dirties            55000.0
# 2115                               Tiny Furniture            50000.0
# 2119                                       Krisha            30000.0
# 2121                                       Exeter            25000.0
#
#       Domestic_Gross  Worldwide_Gross        Profit Original_Language  \
# 1        241063875.0     1.045664e+09  6.350639e+08                en
# 2        459005868.0     1.403014e+09  1.072414e+09                en
# 3        678815482.0     2.048134e+09  1.748134e+09                en
# 4        229024295.0     6.559452e+08  3.559452e+08                en
# 6        200074175.0     8.796209e+08  5.796209e+08                en
# ...              ...              ...           ...               ...
# 2110             0.0     8.555000e+03 -6.144500e+04                en
# 2114             0.0     0.000000e+00 -5.500000e+04                en
# 2115        391674.0     4.241490e+05  3.741490e+05                en
# 2119        144822.0     1.448220e+05  1.148220e+05                en
# 2121             0.0     4.897920e+05  4.647920e+05                en
#
#       Popularity  TMDB_Rating  Vote_Count Quarter_Num Year_x  IMDB_Rating  \
# 1         30.579          6.4        8571           2   2011          6.6
# 2         44.383          7.3       13457           2   2015          7.3
# 3         80.773          8.3       13948           2   2018          8.5
# 4         34.953          6.2        7510           4   2017          6.5
# 6         30.318          6.4        6719           4   2015          6.8
# ...          ...          ...         ...         ...    ...          ...
# 2110      10.357          5.9         175           1   2011          5.8
# 2114       2.971          6.1          57           4   2013          6.8
# 2115       6.695          5.9          82           4   2010          6.2
# 2119       5.288          6.8          86           1   2016          7.2
# 2121       5.934          4.7         121           1   2015          4.5
#
#       Runtime                     Genres  Genre1
# 1       136.0   Action,Adventure,Fantasy  Action
# 2       141.0    Action,Adventure,Sci-Fi  Action
# 3       149.0    Action,Adventure,Sci-Fi  Action
# 4       120.0   Action,Adventure,Fantasy  Action
# 6       148.0  Action,Adventure,Thriller  Action
# ...       ...                        ...     ...
# 2110     87.0       Drama,Horror,Mystery   Drama
# 2114     83.0                Crime,Drama   Crime
# 2115     98.0       Comedy,Drama,Romance  Comedy
# 2119     83.0                      Drama   Drama
# 2121     91.0    Horror,Mystery,Thriller  Horror
#
# [1409 rows x 15 columns]

# %%
final_dataset2.rename(columns = {'Year_x':'Year'},inplace = True)

# %%
final_dataset2 = final_dataset2.drop(['Genres'], axis=1)

# %%
final_dataset2
# Out:
#                                             Title  Production_Budget  \
# 1     Pirates of the Caribbean: On Stranger Tides        410600000.0
# 2                         Avengers: Age of Ultron        330600000.0
# 3                          Avengers: Infinity War        300000000.0
# 4                                  Justice League        300000000.0
# 6                                         Spectre        300000000.0
# ...                                           ...                ...
# 2110                                     Absentia            70000.0
# 2114                                  The Dirties            55000.0
# 2115                               Tiny Furniture            50000.0
# 2119                                       Krisha            30000.0
# 2121                                       Exeter            25000.0
#
#       Domestic_Gross  Worldwide_Gross        Profit Original_Language  \
# 1        241063875.0     1.045664e+09  6.350639e+08                en
# 2        459005868.0     1.403014e+09  1.072414e+09                en
# 3        678815482.0     2.048134e+09  1.748134e+09                en
# 4        229024295.0     6.559452e+08  3.559452e+08                en
# 6        200074175.0     8.796209e+08  5.796209e+08                en
# ...              ...              ...           ...               ...
# 2110             0.0     8.555000e+03 -6.144500e+04                en
# 2114             0.0     0.000000e+00 -5.500000e+04                en
# 2115        391674.0     4.241490e+05  3.741490e+05                en
# 2119        144822.0     1.448220e+05  1.148220e+05                en
# 2121             0.0     4.897920e+05  4.647920e+05                en
#
#       Popularity  TMDB_Rating  Vote_Count Quarter_Num  Year  IMDB_Rating  \
# 1         30.579          6.4        8571           2  2011          6.6
# 2         44.383          7.3       13457           2  2015          7.3
# 3         80.773          8.3       13948           2  2018          8.5
# 4         34.953          6.2        7510           4  2017          6.5
# 6         30.318          6.4        6719           4  2015          6.8
# ...          ...          ...         ...         ...   ...          ...
# 2110      10.357          5.9         175           1  2011          5.8
# 2114       2.971          6.1          57           4  2013          6.8
# 2115       6.695          5.9          82           4  2010          6.2
# 2119       5.288          6.8          86           1  2016          7.2
# 2121       5.934          4.7         121           1  2015          4.5
#
#       Runtime  Genre1
# 1       136.0  Action
# 2       141.0  Action
# 3       149.0  Action
# 4       120.0  Action
# 6       148.0  Action
# ...       ...     ...
# 2110     87.0   Drama
# 2114     83.0   Crime
# 2115     98.0  Comedy
# 2119     83.0   Drama
# 2121     91.0  Horror
#
# [1409 rows x 14 columns]

# %% [markdown]
# ## Final Dataset Visualizations (Trase, Karl, & Al Ameen)

# %%
import numpy as np
avg_profit_by_qtr = final_dataset2.groupby("Quarter_Num")["Profit"].mean()
profit_by_qrt_array = np.array(avg_profit_by_qtr)
profit_by_qrt_array
# Out:
# array([7.93915534e+07, 1.44140263e+08, 8.84100484e+07, 9.53924537e+07])

# %%
# Created Bar Chart for Top Quarters by Profit 
x1 = ['Q1','Q2','Q3','Q4']
a1 = profit_by_qrt_array

sns.barplot(x1,a1)
plt.title('Top Quarters by Profit')
plt.xlabel('Quarters')
plt.ylabel('Average Profit $ (in billions)')
plt.show()
# Out:
# C:\Users\tjester\Anaconda3\envs\learn-env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
count_by_qtr = final_dataset2['Quarter_Num'].value_counts()
count_by_qtr
count_by_qtr_array = np.array(count_by_qtr)

# %%
x1 = ['Q1','Q2','Q3','Q4']
a1 = count_by_qtr_array

sns.barplot(x1,a1)
plt.title('Count of Films Released by Quarter')
plt.xlabel('Quarter')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\tjester\Anaconda3\envs\learn-env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
avg_profit_by_genre = final_dataset2.groupby("Genre")["Profit"].mean()
profit_by_genre_array = np.array(avg_profit_by_genre)
profit_by_genre_array
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-34e4c6b0b4b7> in <module>
# ----> 1 avg_profit_by_genre = final_dataset2.groupby("Genre")["Profit"].mean()
#       2 profit_by_genre_array = np.array(avg_profit_by_genre)
#       3 profit_by_genre_array
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6509         axis = self._get_axis_number(axis)
#    6510
# -> 6511         return DataFrameGroupBy(
#    6512             obj=self,
#    6513             keys=by,
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     523             from pandas.core.groupby.grouper import get_grouper
#     524
# --> 525             grouper, exclusions, obj = get_grouper(
#     526                 obj,
#     527                 keys,
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\groupby\grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     779                 in_axis, name, level, gpr = False, None, gpr, None
#     780             else:
# --> 781                 raise KeyError(gpr)
#     782         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     783             # Add key to exclusions
#
# KeyError: 'Genre'

# %%
final_dataset2 = final_dataset2.sort_values(by = "Profit",ascending = False)
final_dataset2
# Out:
#                       Title  Production_Budget  Domestic_Gross  \
# 3    Avengers: Infinity War        300000000.0     678815482.0
# 26           Jurassic World        215000000.0     652270625.0
# 59                Furious 7        190000000.0     353007020.0
# 20             The Avengers        225000000.0     623279547.0
# 37            Black Panther        200000000.0     700059566.0
# ..                      ...                ...             ...
# 492        The Ridiculous 6         60000000.0             0.0
# 228          Monster Trucks        125000000.0      33370166.0
# 333             The Promise         90000000.0       8224288.0
# 336                  Bright         90000000.0             0.0
# 163         Mars Needs Moms        150000000.0      21392758.0
#
#      Worldwide_Gross        Profit Original_Language  Popularity  TMDB_Rating  \
# 3       2.048134e+09  1.748134e+09                en      80.773          8.3
# 26      1.648855e+09  1.433855e+09                en      20.709          6.6
# 59      1.518723e+09  1.328723e+09                en      20.396          7.3
# 20      1.517936e+09  1.292936e+09                en      50.289          7.6
# 37      1.348258e+09  1.148258e+09                en       2.058          5.1
# ..               ...           ...               ...         ...          ...
# 492     0.000000e+00 -6.000000e+07                en      10.187          5.0
# 228     6.164280e+07 -6.335720e+07                en       8.827          5.9
# 333     1.055142e+07 -7.944858e+07                en      10.158          7.1
# 336     0.000000e+00 -9.000000e+07                en      15.677          6.2
# 163     3.954976e+07 -1.104502e+08                en       8.852          5.7
#
#      Vote_Count Quarter_Num  Year  IMDB_Rating  Runtime     Genre1
# 3         13948           2  2018          8.5    149.0     Action
# 26        14056           2  2015          7.0    124.0     Action
# 59         6538           2  2015          7.2    137.0     Action
# 20        19673           2  2012          8.1    143.0     Action
# 37           11           1  2011          7.3    134.0     Action
# ..          ...         ...   ...          ...      ...        ...
# 492         676           4  2015          4.8    119.0     Comedy
# 228         414           1  2017          5.7    104.0     Action
# 333         195           2  2017          6.1    133.0      Drama
# 336        3181           4  2017          6.4    117.0     Action
# 163         299           1  2011          5.4     88.0  Adventure
#
# [1409 rows x 14 columns]

# %%
final_dataset2['Genre'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Genre'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-65-dc4536ca5228> in <module>
# ----> 1 final_dataset2['Genre'].value_counts()
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'Genre'

# %%
plt.figure(figsize=(25,10))
sns.barplot(x='Genre', y='Profit', data=final_dataset2)
plt.title('Top Genres by Profit')
plt.xlabel('Genres')
plt.ylabel('Profit $ (in billions)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-f1f0fb012074> in <module>
#       1 plt.figure(figsize=(25,10))
# ----> 2 sns.barplot(x='Genre', y='Profit', data=final_dataset2)
#       3 plt.title('Top Genres by Profit')
#       4 plt.xlabel('Genres')
#       5 plt.ylabel('Profit $ (in billions)')
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3167 ):
#    3168
# -> 3169     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3170                           estimator, ci, n_boot, units, seed,
#    3171                           orient, color, palette, saturation,
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1582                  errwidth, capsize, dodge):
#    1583         """Initialize the plotter."""
# -> 1584         self.establish_variables(x, y, hue, data, orient,
#    1585                                  order, hue_order, units)
#    1586         self.establish_colors(color, palette, saturation)
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     151                 if isinstance(var, str):
#     152                     err = "Could not interpret input '{}'".format(var)
# --> 153                     raise ValueError(err)
#     154
#     155             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'Genre'

# %% [markdown]
# ## Testing (Al Ameen, Trase, and Karl)

# %%
final_dataset2.describe()
# Out:
#        Production_Budget  Domestic_Gross  Worldwide_Gross        Profit  \
# count       1.409000e+03    1.409000e+03     1.409000e+03  1.409000e+03
# mean        4.634509e+07    5.882419e+07     1.476204e+08  1.012753e+08
# std         5.563328e+07    8.521097e+07     2.356821e+08  1.948675e+08
# min         2.500000e+04    0.000000e+00     0.000000e+00 -1.104502e+08
# 25%         1.000000e+07    6.352306e+06     1.430493e+07 -3.968800e+04
# 50%         2.500000e+07    3.069800e+07     5.979507e+07  2.803172e+07
# 75%         5.800000e+07    7.139912e+07     1.658891e+08  1.122567e+08
# max         4.106000e+08    7.000596e+08     2.048134e+09  1.748134e+09
#
#         Popularity  TMDB_Rating    Vote_Count  IMDB_Rating      Runtime
# count  1409.000000  1409.000000   1409.000000  1409.000000  1409.000000
# mean     13.113166     6.328176   2131.038325     6.428531   108.523776
# std       7.577189     0.819095   2830.294559     0.933055    16.768084
# min       0.600000     2.100000      5.000000     1.600000    63.000000
# 25%       8.426000     5.800000    380.000000     5.800000    96.000000
# 50%      11.250000     6.300000   1055.000000     6.500000   106.000000
# 75%      15.762000     6.900000   2703.000000     7.100000   118.000000
# max      80.773000     8.300000  22186.000000     8.800000   180.000000

# %%
pop_mean= final_dataset2.Profit.mean()
pop_std = final_dataset2.Profit.std()

# %%
# Selecting a random sample
random_sample = final_dataset2.sample(n=100)
random_sample
# Out:
#                             Title  Production_Budget  Domestic_Gross  \
# 1688     Ain't Them Bodies Saints          5000000.0        391611.0
# 1370                       Stoker         12000000.0       1703125.0
# 1089                    You Again         20000000.0      25702053.0
# 1651                       Oculus          5000000.0      27695246.0
# 862   Baahubali 2: The Conclusion         30000000.0      18985794.0
# ...                           ...                ...             ...
# 307                       Ben-Hur         95000000.0      26410477.0
# 1252            A Most Wanted Man         15000000.0      17237855.0
# 351                         RED 2         84000000.0      53262560.0
# 762                   Broken City         35000000.0      19701164.0
# 1739                   Stake Land          4000000.0         33245.0
#
#       Worldwide_Gross       Profit Original_Language  Popularity  TMDB_Rating  \
# 1688        1075009.0   -3924991.0                en       8.166          6.2
# 1370       12034913.0      34913.0                en      10.738          6.6
# 1089       32838945.0   12838945.0                en      10.208          6.2
# 1651       44115496.0   39115496.0                en      10.841          6.4
# 862       263502914.0  233502914.0                te      10.406          7.0
# ...               ...          ...               ...         ...          ...
# 307        91669648.0   -3330352.0                en      10.110          5.6
# 1252       36068890.0   21068890.0                en      10.267          6.5
# 351       141507355.0   57507355.0                en      14.994          6.5
# 762        34480045.0    -519955.0                en      13.646          5.9
# 1739         679482.0   -3320518.0                en       8.799          6.2
#
#       Vote_Count Quarter_Num  Year  IMDB_Rating  Runtime  Genre1
# 1688         217           3  2013          6.4     96.0   Crime
# 1370        1282           1  2013          6.8     99.0   Drama
# 1089         734           3  2010          5.8    105.0  Comedy
# 1651        1747           2  2014          6.5    104.0  Horror
# 862          252           2  2017          8.3    167.0  Action
# ...          ...         ...   ...          ...      ...     ...
# 307         1068           3  2016          5.7    123.0  Action
# 1252         784           3  2014          6.8    122.0   Crime
# 351         2368           3  2013          6.6    116.0  Action
# 762          814           1  2013          6.2    109.0   Crime
# 1739         415           4  2010          6.5     98.0   Drama
#
# [100 rows x 14 columns]

# %%
sample_mean = random_sample.Profit.mean()
sample_std = random_sample.Profit.std()
print(sample_mean,sample_std)
print(pop_mean,pop_std)
# Out:
# 65545814.56 138227410.05838454
# 101275270.7459191 194867455.97646457

# %%
# H0 = sample_mean = 0
# H1 = sample_mean != 0
"""
import scipy.stats as stats
from math import sqrt 

z = (sample_mean - pop_mean)/(pop_std / (sqrt(100)))
z

area_under = stats.norm.cdf(z)
print(area_under)"""
# Out:
# '\nimport scipy.stats as stats\nfrom math import sqrt \n\nz = (sample_mean - pop_mean)/(pop_std / (sqrt(100)))\nz\n\narea_under = stats.norm.cdf(z)\nprint(area_under)'

# %%
final_corr_matrix = final_dataset2.corr
print(final_corr_matrix)
# Out:
# <bound method DataFrame.corr of                       Title  Production_Budget  Domestic_Gross  \
# 3    Avengers: Infinity War        300000000.0     678815482.0
# 26           Jurassic World        215000000.0     652270625.0
# 59                Furious 7        190000000.0     353007020.0
# 20             The Avengers        225000000.0     623279547.0
# 37            Black Panther        200000000.0     700059566.0
# ..                      ...                ...             ...
# 492        The Ridiculous 6         60000000.0             0.0
# 228          Monster Trucks        125000000.0      33370166.0
# 333             The Promise         90000000.0       8224288.0
# 336                  Bright         90000000.0             0.0
# 163         Mars Needs Moms        150000000.0      21392758.0
#
#      Worldwide_Gross        Profit Original_Language  Popularity  TMDB_Rating  \
# 3       2.048134e+09  1.748134e+09                en      80.773          8.3
# 26      1.648855e+09  1.433855e+09                en      20.709          6.6
# 59      1.518723e+09  1.328723e+09                en      20.396          7.3
# 20      1.517936e+09  1.292936e+09                en      50.289          7.6
# 37      1.348258e+09  1.148258e+09                en       2.058          5.1
# ..               ...           ...               ...         ...          ...
# 492     0.000000e+00 -6.000000e+07                en      10.187          5.0
# 228     6.164280e+07 -6.335720e+07                en       8.827          5.9
# 333     1.055142e+07 -7.944858e+07                en      10.158          7.1
# 336     0.000000e+00 -9.000000e+07                en      15.677          6.2
# 163     3.954976e+07 -1.104502e+08                en       8.852          5.7
#
#      Vote_Count Quarter_Num  Year  IMDB_Rating  Runtime     Genre1
# 3         13948           2  2018          8.5    149.0     Action
# 26        14056           2  2015          7.0    124.0     Action
# 59         6538           2  2015          7.2    137.0     Action
# 20        19673           2  2012          8.1    143.0     Action
# 37           11           1  2011          7.3    134.0     Action
# ..          ...         ...   ...          ...      ...        ...
# 492         676           4  2015          4.8    119.0     Comedy
# 228         414           1  2017          5.7    104.0     Action
# 333         195           2  2017          6.1    133.0      Drama
# 336        3181           4  2017          6.4    117.0     Action
# 163         299           1  2011          5.4     88.0  Adventure
#
# [1409 rows x 14 columns]>

# %%
"""import seaborn as sn
import matplotlib.pyplot as plt

sn.heatmap(final_corr_matrix, annot=True)
plt.show()"""
# Out:
# 'import seaborn as sn\nimport matplotlib.pyplot as plt\n\nsn.heatmap(final_corr_matrix, annot=True)\nplt.show()'

# %%
genre_unique = pd.array(final_dataset2.Genre.unique())
genre_unique
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-74-10964e79d1af> in <module>
# ----> 1 genre_unique = pd.array(final_dataset2.Genre.unique())
#       2 genre_unique
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Genre'

# %%
"""import numpy as np
from scipy import stats

a = genre_unique
b = profit_by_genre_array
stats.pointbiserialr(a, b)
np.corrcoef(a, b)"""

# %% [markdown]
# ## Correlation Coefficient

# %%
# Gives the correlation coefficient for quantitative variables
final_dataset2.corr()
# Out:
#                    Production_Budget  Domestic_Gross  Worldwide_Gross  \
# Production_Budget           1.000000        0.712885         0.788139
# Domestic_Gross              0.712885        1.000000         0.943091
# Worldwide_Gross             0.788139        0.943091         1.000000
# Profit                      0.667721        0.937097         0.984440
# Popularity                  0.569619        0.546848         0.588284
# TMDB_Rating                 0.100893        0.238997         0.226135
# Vote_Count                  0.611672        0.715448         0.729845
# IMDB_Rating                 0.146080        0.272525         0.258199
# Runtime                     0.369955        0.305603         0.320046
#
#                      Profit  Popularity  TMDB_Rating  Vote_Count  IMDB_Rating  \
# Production_Budget  0.667721    0.569619     0.100893    0.611672     0.146080
# Domestic_Gross     0.937097    0.546848     0.238997    0.715448     0.272525
# Worldwide_Gross    0.984440    0.588284     0.226135    0.729845     0.258199
# Profit             1.000000    0.548877     0.244695    0.708082     0.270574
# Popularity         0.548877    1.000000     0.308841    0.691446     0.260556
# TMDB_Rating        0.244695    0.308841     1.000000    0.414737     0.860668
# Vote_Count         0.708082    0.691446     0.414737    1.000000     0.409811
# IMDB_Rating        0.270574    0.260556     0.860668    0.409811     1.000000
# Runtime            0.281459    0.318700     0.405830    0.395748     0.418061
#
#                     Runtime
# Production_Budget  0.369955
# Domestic_Gross     0.305603
# Worldwide_Gross    0.320046
# Profit             0.281459
# Popularity         0.318700
# TMDB_Rating        0.405830
# Vote_Count         0.395748
# IMDB_Rating        0.418061
# Runtime            1.000000

# %%
# Run T-Test
sample = final_dataset2[final_dataset2['Quarter_Num']=='2']
x_bar_final = sample['Profit'].mean()
mu_final = final_dataset2['Profit'].mean()
sigma_final = sample['Profit'].std()
n_final = len(sample)

print(x_bar_final, mu_final)
# Out:
# 144140262.7795031 101275270.7459191

# %%
# Our hypothesis

# H0 = xbar <= mu_final
# HA = xbar > mu_final

# %%
# 95% test
t_final = (x_bar_final -  mu_final)/(sigma_final/np.sqrt(n_final))
t_final
# Out:
# 2.8914676557708696

# %%
# Set up figure and axes
fig, ax = plt.subplots(figsize=(8,5))

# Generate data for plotting the PDF
# (1) generate points on the x axis between -5 and 5:
x = np.linspace(-5, 5, 200)
# (2) use stats.t.pdf to get values on the probability density
# function for the t-distribution
y = stats.t.pdf(x, final_dataset2, 0, 1)

# Plot the PDF as a line graph
ax.plot(x, y, color='darkblue', label="t-distribution PDF")

# Plot a vertical line for our measured difference in sales t-statistic
ax.axvline(t, color='red', linestyle='--', lw=5,label='observed t-statistic')

ax.legend();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-79-8868be210e01> in <module>
#       7 # (2) use stats.t.pdf to get values on the probability density
#       8 # function for the t-distribution
# ----> 9 y = stats.t.pdf(x, final_dataset2, 0, 1)
#      10
#      11 # Plot the PDF as a line graph
#
# NameError: name 'stats' is not defined

# %%
#
stats.t.cdf(t_final, df=(n_final-1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-80-90a0ca3da6f4> in <module>
#       1 #
# ----> 2 stats.t.cdf(t_final, df=(n_final-1))
#
# NameError: name 'stats' is not defined

# %%
t_crit = stats.t.ppf(1 - 0.05, df=(n_final-1))
t_crit
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-81-d3dcfdf731f5> in <module>
# ----> 1 t_crit = stats.t.ppf(1 - 0.05, df=(n_final-1))
#       2 t_crit
#
# NameError: name 'stats' is not defined

# %%
#Pushing p
p_value = stats.t.sf(t_final, df = (n_final-1))
p_value
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-82-e552892e7705> in <module>
#       1 #Pushing p
# ----> 2 p_value = stats.t.sf(t_final, df = (n_final-1))
#       3 p_value
#
# NameError: name 'stats' is not defined

# %% [markdown]
# Based on our p-value, we can be confident that 95% of the time the mean of the movies produced in Q2 are significantly greater than the population mean.
#
# Given our alpha of 0.05, this p-value is smaller than our alpha, therefore we can again say that we reject the null hypothesis at a significance level of 0.05.

# %% [markdown]
# ## Carolyn, Alameen, and Karl - Runtime vs Profit on Final Dataset

# %%
final_dataset2 = pd.read_csv('../../zippedData/final_dataset2.csv')

# %%
final_dataset2
# Out:
#       Unnamed: 0                   Title  Production_Budget  Domestic_Gross  \
# 0              3  Avengers: Infinity War        300000000.0     678815482.0
# 1             26          Jurassic World        215000000.0     652270625.0
# 2             59               Furious 7        190000000.0     353007020.0
# 3             20            The Avengers        225000000.0     623279547.0
# 4             37           Black Panther        200000000.0     700059566.0
# ...          ...                     ...                ...             ...
# 1404         492        The Ridiculous 6         60000000.0             0.0
# 1405         228          Monster Trucks        125000000.0      33370166.0
# 1406         333             The Promise         90000000.0       8224288.0
# 1407         336                  Bright         90000000.0             0.0
# 1408         163         Mars Needs Moms        150000000.0      21392758.0
#
#       Worldwide_Gross        Profit Original_Language  Popularity  \
# 0        2.048134e+09  1.748134e+09                en      80.773
# 1        1.648855e+09  1.433855e+09                en      20.709
# 2        1.518723e+09  1.328723e+09                en      20.396
# 3        1.517936e+09  1.292936e+09                en      50.289
# 4        1.348258e+09  1.148258e+09                en       2.058
# ...               ...           ...               ...         ...
# 1404     0.000000e+00 -6.000000e+07                en      10.187
# 1405     6.164280e+07 -6.335720e+07                en       8.827
# 1406     1.055142e+07 -7.944858e+07                en      10.158
# 1407     0.000000e+00 -9.000000e+07                en      15.677
# 1408     3.954976e+07 -1.104502e+08                en       8.852
#
#       TMDB_Rating  Vote_Count  Quarter_Num  Year  IMDB_Rating  Runtime  \
# 0             8.3       13948            2  2018          8.5    149.0
# 1             6.6       14056            2  2015          7.0    124.0
# 2             7.3        6538            2  2015          7.2    137.0
# 3             7.6       19673            2  2012          8.1    143.0
# 4             5.1          11            1  2011          7.3    134.0
# ...           ...         ...          ...   ...          ...      ...
# 1404          5.0         676            4  2015          4.8    119.0
# 1405          5.9         414            1  2017          5.7    104.0
# 1406          7.1         195            2  2017          6.1    133.0
# 1407          6.2        3181            4  2017          6.4    117.0
# 1408          5.7         299            1  2011          5.4     88.0
#
#          Genre1  Runtime_bin
# 0        Action        150.0
# 1        Action        100.0
# 2        Action        150.0
# 3        Action        150.0
# 4        Action        150.0
# ...         ...          ...
# 1404     Comedy        100.0
# 1405     Action        100.0
# 1406      Drama        150.0
# 1407     Action        100.0
# 1408  Adventure        100.0
#
# [1408 rows x 16 columns]

# %%
final_dataset2 = final_dataset2[final_dataset2.Genre1 !='Family']

# %%
final_dataset2
# Out:
#       Unnamed: 0                   Title  Production_Budget  Domestic_Gross  \
# 0              3  Avengers: Infinity War        300000000.0     678815482.0
# 1             26          Jurassic World        215000000.0     652270625.0
# 2             59               Furious 7        190000000.0     353007020.0
# 3             20            The Avengers        225000000.0     623279547.0
# 4             37           Black Panther        200000000.0     700059566.0
# ...          ...                     ...                ...             ...
# 1404         492        The Ridiculous 6         60000000.0             0.0
# 1405         228          Monster Trucks        125000000.0      33370166.0
# 1406         333             The Promise         90000000.0       8224288.0
# 1407         336                  Bright         90000000.0             0.0
# 1408         163         Mars Needs Moms        150000000.0      21392758.0
#
#       Worldwide_Gross        Profit Original_Language  Popularity  \
# 0        2.048134e+09  1.748134e+09                en      80.773
# 1        1.648855e+09  1.433855e+09                en      20.709
# 2        1.518723e+09  1.328723e+09                en      20.396
# 3        1.517936e+09  1.292936e+09                en      50.289
# 4        1.348258e+09  1.148258e+09                en       2.058
# ...               ...           ...               ...         ...
# 1404     0.000000e+00 -6.000000e+07                en      10.187
# 1405     6.164280e+07 -6.335720e+07                en       8.827
# 1406     1.055142e+07 -7.944858e+07                en      10.158
# 1407     0.000000e+00 -9.000000e+07                en      15.677
# 1408     3.954976e+07 -1.104502e+08                en       8.852
#
#       TMDB_Rating  Vote_Count  Quarter_Num  Year  IMDB_Rating  Runtime  \
# 0             8.3       13948            2  2018          8.5    149.0
# 1             6.6       14056            2  2015          7.0    124.0
# 2             7.3        6538            2  2015          7.2    137.0
# 3             7.6       19673            2  2012          8.1    143.0
# 4             5.1          11            1  2011          7.3    134.0
# ...           ...         ...          ...   ...          ...      ...
# 1404          5.0         676            4  2015          4.8    119.0
# 1405          5.9         414            1  2017          5.7    104.0
# 1406          7.1         195            2  2017          6.1    133.0
# 1407          6.2        3181            4  2017          6.4    117.0
# 1408          5.7         299            1  2011          5.4     88.0
#
#          Genre1  Runtime_bin
# 0        Action        150.0
# 1        Action        100.0
# 2        Action        150.0
# 3        Action        150.0
# 4        Action        150.0
# ...         ...          ...
# 1404     Comedy        100.0
# 1405     Action        100.0
# 1406      Drama        150.0
# 1407     Action        100.0
# 1408  Adventure        100.0
#
# [1408 rows x 16 columns]

# %%
final_dataset2['Runtime'] = np.round(final_dataset2['Runtime']/50 * 50)
# Out:
# <ipython-input-67-6e1110247739>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_dataset2['Runtime'] = np.round(final_dataset2['Runtime']/50 * 50)

# %%
grouped = final_dataset2.groupby('Runtime')['Profit'].mean().reset_index()
grouped
# Out:
#     Runtime        Profit
# 0      63.0  2.014561e+07
# 1      75.0  2.982726e+07
# 2      79.0  9.659960e+05
# 3      80.0  6.463326e+07
# 4      81.0  3.597947e+07
# ..      ...           ...
# 85    168.0  8.586489e+07
# 86    169.0  6.341915e+08
# 87    172.0  8.198387e+06
# 88    176.0 -3.393334e+06
# 89    180.0  2.898704e+08
#
# [90 rows x 2 columns]

# %%
plt.bar(grouped['Runtime'], grouped['Profit'])
plt.xlabel('Runtime Minutes')
plt.ylabel('Average Profit $ (in billions)')
plt.title('Average Profit vs Runtime Minutes')
plt.show()

# %%
sixty_to_ninety = final_dataset2[final_dataset2['Runtime'] <= 90 ]
sixty_to_ninety
# Out:
#       Unnamed: 0                       Title  Production_Budget  \
# 14           385             Despicable Me 3         75000000.0
# 27           382     The Secret Life of Pets         75000000.0
# 30           301  Ice Age: Continental Drift         95000000.0
# 67           153             Kung Fu Panda 2        150000000.0
# 93           202               Puss in Boots        130000000.0
# ...          ...                         ...                ...
# 1319        1273           The Son of No One         15000000.0
# 1320        1146                Action Point         19000000.0
# 1343        1187                    Forsaken         18000000.0
# 1397         592                   Jonah Hex         47000000.0
# 1408         163             Mars Needs Moms        150000000.0
#
#       Domestic_Gross  Worldwide_Gross       Profit Original_Language  \
# 14       264624300.0     1.034728e+09  959727750.0                en
# 27       368384330.0     8.867505e+08  811750534.0                en
# 30       161321843.0     8.797651e+08  784765137.0                en
# 67       165249063.0     6.648375e+08  514837547.0                en
# 93       149260504.0     5.549875e+08  424987477.0                en
# ...              ...              ...          ...               ...
# 1319         30680.0     1.148578e+06  -13851422.0                en
# 1320       5059608.0     5.103675e+06  -13896325.0                en
# 1343             0.0     0.000000e+00  -18000000.0                en
# 1397      10547117.0     1.102270e+07  -35977304.0                en
# 1408      21392758.0     3.954976e+07 -110450242.0                en
#
#       Popularity  TMDB_Rating  Vote_Count  Quarter_Num  Year  IMDB_Rating  \
# 14        16.407          6.3        4106            2  2017          6.3
# 27         9.909          6.1        5374            3  2016          6.5
# 30        17.537          6.3        4598            3  2012          6.6
# 67        17.363          6.7        3628            2  2011          7.2
# 93         9.078          6.3        1422            4  2011          6.6
# ...          ...          ...         ...          ...   ...          ...
# 1319       7.586          5.1         156            4  2011          5.1
# 1320      12.840          5.2         136            2  2018          5.0
# 1343       9.472          5.9         161            1  2016          6.3
# 1397      13.467          4.6         708            2  2010          4.7
# 1408       8.852          5.7         299            1  2011          5.4
#
#       Runtime     Genre1  Runtime_bin
# 14       89.0  Adventure        100.0
# 27       87.0  Adventure        100.0
# 30       88.0  Adventure        100.0
# 67       90.0     Action        100.0
# 93       90.0     Action        100.0
# ...       ...        ...          ...
# 1319     90.0     Action        100.0
# 1320     85.0     Comedy        100.0
# 1343     90.0     Action        100.0
# 1397     81.0     Action        100.0
# 1408     88.0  Adventure        100.0
#
# [157 rows x 16 columns]

# %%
nintey_to_onetwenty = final_dataset2[(final_dataset2['Runtime'] <= 120) & (final_dataset2['Runtime'] > 90) ]
nintey_to_onetwenty
# Out:
#       Unnamed: 0                           Title  Production_Budget  \
# 6            142                          Frozen        150000000.0
# 8            402                         Minions         74000000.0
# 10            39                   Incredibles 2        200000000.0
# 17           381                 Despicable Me 2         76000000.0
# 20           315  Jumanji: Welcome to the Jungle         90000000.0
# ...          ...                             ...                ...
# 1401         617                      Foodfight!         45000000.0
# 1403         210                        R.I.P.D.        130000000.0
# 1404         492                The Ridiculous 6         60000000.0
# 1405         228                  Monster Trucks        125000000.0
# 1407         336                          Bright         90000000.0
#
#       Domestic_Gross  Worldwide_Gross        Profit Original_Language  \
# 6        400738009.0     1.272470e+09  1.122470e+09                en
# 8        336045770.0     1.160336e+09  1.086336e+09                en
# 10       608581744.0     1.242521e+09  1.042521e+09                en
# 17       368065385.0     9.752168e+08  8.992168e+08                en
# 20       404508916.0     9.644962e+08  8.744962e+08                en
# ...              ...              ...           ...               ...
# 1401             0.0     7.370600e+04 -4.492629e+07                en
# 1403      33618855.0     7.907668e+07 -5.092332e+07                en
# 1404             0.0     0.000000e+00 -6.000000e+07                en
# 1405      33370166.0     6.164280e+07 -6.335720e+07                en
# 1407             0.0     0.000000e+00 -9.000000e+07                en
#
#       Popularity  TMDB_Rating  Vote_Count  Quarter_Num  Year  IMDB_Rating  \
# 6          9.678          5.8         987            1  2010          7.5
# 8          9.338          6.4        7343            3  2015          6.4
# 10        36.286          7.6        6354            2  2018          7.7
# 17        19.014          6.9        7319            3  2013          7.4
# 20        20.395          6.7        7213            4  2017          7.0
# ...          ...          ...         ...          ...   ...          ...
# 1401       4.705          2.1          46            2  2013          1.9
# 1403      21.377          5.6        2047            3  2013          5.6
# 1404      10.187          5.0         676            4  2015          4.8
# 1405       8.827          5.9         414            1  2017          5.7
# 1407      15.677          6.2        3181            4  2017          6.4
#
#       Runtime     Genre1  Runtime_bin
# 6       102.0  Adventure        100.0
# 8        91.0  Adventure        100.0
# 10      118.0     Action        100.0
# 17       98.0  Adventure        100.0
# 20      119.0     Action        100.0
# ...       ...        ...          ...
# 1401     91.0     Action        100.0
# 1403     96.0     Action        100.0
# 1404    119.0     Comedy        100.0
# 1405    104.0     Action        100.0
# 1407    117.0     Action        100.0
#
# [950 rows x 16 columns]

# %%
onetwenty_to_onefifty = final_dataset2[(final_dataset2['Runtime'] <= 150) & (final_dataset2['Runtime'] > 120) ]
onetwenty_to_onefifty
# Out:
#       Unnamed: 0                             Title  Production_Budget  \
# 0              3            Avengers: Infinity War        300000000.0
# 1             26                    Jurassic World        215000000.0
# 2             59                         Furious 7        190000000.0
# 3             20                      The Avengers        225000000.0
# 4             37                     Black Panther        200000000.0
# ...          ...                               ...                ...
# 1398         694  USS Indianapolis: Men of Courage         40000000.0
# 1399         578                          Child 44         50000000.0
# 1400         450                     Live by Night         65000000.0
# 1402         419                          Blackhat         70000000.0
# 1406         333                       The Promise         90000000.0
#
#       Domestic_Gross  Worldwide_Gross        Profit Original_Language  \
# 0        678815482.0     2.048134e+09  1.748134e+09                en
# 1        652270625.0     1.648855e+09  1.433855e+09                en
# 2        353007020.0     1.518723e+09  1.328723e+09                en
# 3        623279547.0     1.517936e+09  1.292936e+09                en
# 4        700059566.0     1.348258e+09  1.148258e+09                en
# ...              ...              ...           ...               ...
# 1398             0.0     1.663785e+06 -3.833622e+07                en
# 1399       1224330.0     8.004221e+06 -4.199578e+07                en
# 1400      10378555.0     2.177443e+07 -4.322557e+07                en
# 1402       8005980.0     1.966500e+07 -5.033500e+07                en
# 1406       8224288.0     1.055142e+07 -7.944858e+07                en
#
#       Popularity  TMDB_Rating  Vote_Count  Quarter_Num  Year  IMDB_Rating  \
# 0         80.773          8.3       13948            2  2018          8.5
# 1         20.709          6.6       14056            2  2015          7.0
# 2         20.396          7.3        6538            2  2015          7.2
# 3         50.289          7.6       19673            2  2012          8.1
# 4          2.058          5.1          11            1  2011          7.3
# ...          ...          ...         ...          ...   ...          ...
# 1398      11.221          5.9         328            1  2017          5.2
# 1399      26.386          6.2         903            2  2015          6.5
# 1400      11.322          6.2         759            4  2016          6.4
# 1402      16.824          5.3        1165            1  2015          5.4
# 1406      10.158          7.1         195            2  2017          6.1
#
#       Runtime  Genre1  Runtime_bin
# 0       149.0  Action        150.0
# 1       124.0  Action        100.0
# 2       137.0  Action        150.0
# 3       143.0  Action        150.0
# 4       134.0  Action        150.0
# ...       ...     ...          ...
# 1398    128.0  Action        150.0
# 1399    137.0   Crime        150.0
# 1400    129.0  Action        150.0
# 1402    133.0  Action        150.0
# 1406    133.0   Drama        150.0
#
# [274 rows x 16 columns]

# %%
onefifty_to_oneeighty = final_dataset2[(final_dataset2['Runtime'] <= 180) & (final_dataset2['Runtime'] > 150) ]
onefifty_to_oneeighty
# Out:
#       Unnamed: 0                                Title  Production_Budget  \
# 15            55       Transformers: Dark of the Moon        195000000.0
# 18            28      Transformers: Age of Extinction        210000000.0
# 28             8                The Dark Knight Rises        275000000.0
# 31            15    The Hobbit: An Unexpected Journey        250000000.0
# 35            16  The Hobbit: The Desolation of Smaug        250000000.0
# 49            14   Batman v Superman: Dawn of Justice        250000000.0
# 73           112                         Interstellar        165000000.0
# 97           179                         The Revenant        135000000.0
# 102           25        Transformers: The Last Knight        217000000.0
# 117          273                     Django Unchained        100000000.0
# 150          277              The Wolf of Wall Street        100000000.0
# 151         1494                               Dangal          9500000.0
# 180          862          Baahubali 2: The Conclusion         30000000.0
# 276          321      The Girl with the Dragon Tattoo         90000000.0
# 361         1316                    Bajrangi Bhaijaan         13000000.0
# 413          455                    The Hateful Eight         62000000.0
# 423          528                     Zero Dark Thirty         52500000.0
# 445           71                    Blade Runner 2049        185000000.0
# 483          596                            Prisoners         46000000.0
# 546         1723                              Boyhood          4000000.0
# 698          270                          Cloud Atlas        102000000.0
# 795         1127                              Admiral         20000000.0
# 1088        1764                       American Honey          3500000.0
# 1170        1498                     Jab Tak Hai Jaan          9200000.0
# 1304        1011                              Dhoom 3         24000000.0
# 1306        1120                             Suspiria         20000000.0
# 1360         593                              Silence         46500000.0
#
#       Domestic_Gross  Worldwide_Gross       Profit Original_Language  \
# 15       352390543.0     1.123791e+09  928790543.0                en
# 18       245439076.0     1.104039e+09  894039076.0                en
# 28       448139099.0     1.084439e+09  809439099.0                en
# 31       303003568.0     1.017004e+09  767003568.0                en
# 35       258366855.0     9.603669e+08  710366855.0                en
# 49       330360194.0     8.675003e+08  617500281.0                en
# 73       188017894.0     6.663794e+08  501379375.0                en
# 97       183637894.0     5.329383e+08  397938302.0                en
# 102      130168683.0     6.028933e+08  385893340.0                en
# 117      162805434.0     4.499483e+08  349948323.0                en
# 150      116900694.0     3.898704e+08  289870414.0                en
# 151       12391761.0     2.946546e+08  285154618.0                hi
# 180       18985794.0     2.635029e+08  233502914.0                te
# 276      102515793.0     2.393740e+08  149373970.0                en
# 361        8178001.0     1.217783e+08  108778347.0                hi
# 413       54117416.0     1.478649e+08   85864886.0                en
# 423       95720716.0     1.346124e+08   82112435.0                en
# 445       92054159.0     2.593574e+08   74357408.0                en
# 483       61002302.0     1.134023e+08   67402302.0                en
# 546       25379975.0     5.727305e+07   53273049.0                en
# 698       27108272.0     1.306732e+08   28673154.0                en
# 795              0.0     3.858505e+07   18585047.0                nl
# 1088        663247.0     2.611750e+06    -888250.0                en
# 1170       3047539.0     5.806666e+06   -3393334.0                hi
# 1304       8031955.0     1.172362e+07  -12276380.0                hi
# 1306       2483472.0     7.034615e+06  -12965385.0                en
# 1360       7100177.0     2.372663e+07  -22773374.0                en
#
#       Popularity  TMDB_Rating  Vote_Count  Quarter_Num  Year  IMDB_Rating  \
# 15         5.339          6.1        4961            2  2011          6.2
# 18        20.961          5.8        4805            2  2014          5.7
# 28        26.220          7.7       13933            3  2012          8.4
# 31        26.939          7.2       12076            4  2012          7.9
# 35        21.275          7.6        7739            4  2013          7.8
# 49        28.088          5.8       11991            1  2016          6.5
# 73        28.440          8.2       18597            4  2014          8.6
# 97        19.410          7.4       11064            4  2015          8.0
# 102       24.258          6.0        3255            2  2017          5.2
# 117       21.260          8.0       15725            4  2012          8.4
# 150       29.518          7.9       12411            4  2013          8.2
# 151       10.022          8.1         358            4  2016          8.5
# 180       10.406          7.0         252            2  2017          8.3
# 276       17.823          7.3        3971            4  2011          7.8
# 361        7.122          7.9         232            3  2015          8.0
# 413       20.681          7.7        8065            4  2015          7.8
# 423       14.239          6.9        2553            4  2012          7.4
# 445       48.571          7.4        6679            4  2017          8.0
# 483       14.358          8.0        5785            3  2013          8.1
# 546       11.141          7.5        3097            3  2014          7.9
# 698       14.681          6.8        4505            4  2012          7.4
# 795        5.466          6.4          86            1  2016          7.0
# 1088       8.778          6.7         417            3  2016          7.0
# 1170       7.701          6.9         107            4  2012          6.8
# 1304       6.798          5.9         136            4  2013          5.4
# 1306      16.925          7.0         752            4  2018          6.8
# 1360      10.617          7.1        1560            4  2016          7.2
#
#       Runtime     Genre1  Runtime_bin
# 15      154.0     Action        150.0
# 18      165.0     Action        150.0
# 28      164.0     Action        150.0
# 31      169.0  Adventure        150.0
# 35      161.0  Adventure        150.0
# 49      151.0     Action        150.0
# 73      169.0  Adventure        150.0
# 97      156.0     Action        150.0
# 102     154.0     Action        150.0
# 117     165.0      Drama        150.0
# 150     180.0  Biography        200.0
# 151     161.0     Action        150.0
# 180     167.0     Action        150.0
# 276     158.0      Crime        150.0
# 361     163.0     Action        150.0
# 413     168.0      Crime        150.0
# 423     157.0      Drama        150.0
# 445     164.0      Drama        150.0
# 483     153.0      Crime        150.0
# 546     165.0      Drama        150.0
# 698     172.0     Action        150.0
# 795     151.0     Action        150.0
# 1088    163.0  Adventure        150.0
# 1170    176.0      Drama        200.0
# 1304    172.0     Action        150.0
# 1306    152.0    Fantasy        150.0
# 1360    161.0  Adventure        150.0

# %%
sixty_to_ninety['Profit'].mean()
# Out:
# 57544763.280254774

# %%
nintey_to_onetwenty['Profit'].mean()
# Out:
# 77664945.10210526

# %%
onetwenty_to_onefifty['Profit'].mean()
# Out:
# 186111242.73722628

# %%
onefifty_to_oneeighty['Profit'].mean()
# Out:
# 288405577.1481481

# %%
x = [57544763.280254774, 77664945.10210526, 186111242.73722628, 288405577.1481481]
y = ['60-90', '90-120', '120-150', '150-180']

sns.barplot(x,y)
plt.title('Average Profit vs Runtime Minutes')
plt.xlabel('Average Profit $ (in millions)')
plt.ylabel('Runtime Minutes')
plt.show()
# Out:
# /Users/cisahack/apps/anaconda3/envs/learn-env/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sixty_to_ninety.index
# Out:
# Int64Index([  14,   27,   30,   67,   93,   94,  100,  128,  160,  208,
#             ...
#             1253, 1258, 1271, 1287, 1295, 1319, 1320, 1343, 1397, 1408],
#            dtype='int64', length=157)

# %%
nintey_to_onetwenty.index
# Out:
# Int64Index([   6,    8,   10,   17,   20,   21,   22,   25,   26,   29,
#             ...
#             1390, 1391, 1392, 1393, 1395, 1401, 1403, 1404, 1405, 1407],
#            dtype='int64', length=950)

# %%
onetwenty_to_onefifty.index
# Out:
# Int64Index([   0,    1,    2,    3,    4,    5,    9,   11,   12,   13,
#             ...
#             1378, 1380, 1381, 1394, 1396, 1398, 1399, 1400, 1402, 1406],
#            dtype='int64', length=274)

# %%
onefifty_to_oneeighty.index
# Out:
# Int64Index([  15,   18,   28,   31,   35,   49,   73,   97,  102,  117,  150,
#              151,  180,  276,  361,  413,  423,  445,  483,  546,  698,  795,
#             1088, 1170, 1304, 1306, 1360],
#            dtype='int64')
