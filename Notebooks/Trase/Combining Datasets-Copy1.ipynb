# %% [markdown]
# ## IMDB Cleaning (Trase, Mark, Karl Durant)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sqlite3
tips = sns.load_dataset('tips')
sns.set_theme(style="whitegrid")
# %matplotlib inline

# %%
conn = sqlite3.connect('../../zippedData/im (2).db')

# %%
pd.read_sql("""
SELECT *
FROM movie_basics

""", conn)
# Out:
#          movie_id                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# 2                        The Other Side of the Wind        2018
# 3                                   Sabse Bada Sukh        2018
# 4                             La Telenovela Errante        2017
# ...                                             ...         ...
# 146139                          Kuambil Lagi Hatiku        2019
# 146140  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141                              Dankyavar Danka        2013
# 146142                                       6 Gunn        2017
# 146143               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes                genres
# 0                 175.0    Action,Crime,Drama
# 1                 114.0       Biography,Drama
# 2                 122.0                 Drama
# 3                   NaN          Comedy,Drama
# 4                  80.0  Comedy,Drama,Fantasy
# ...                 ...                   ...
# 146139            123.0                 Drama
# 146140              NaN           Documentary
# 146141              NaN                Comedy
# 146142            116.0                  None
# 146143              NaN           Documentary
#
# [146144 rows x 6 columns]

# %%
pd.read_sql("""
SELECT MOVIE_ID AS Movie_ID, AVERAGERATING AS Avg_Rating, NUMVOTES AS Number_of_Votes, PRIMARY_TITLE AS Title, START_YEAR AS Year, RUNTIME_MINUTES AS Minutes, GENRES AS Genres
FROM MOVIE_RATINGS
JOIN MOVIE_BASICS
    USING(MOVIE_ID)
WHERE NUMVOTES > 15000
ORDER BY NUMVOTES DESC
;
""", conn).head()
# Out:
#     Movie_ID  Avg_Rating  Number_of_Votes                  Title  Year  \
# 0  tt1375666         8.8          1841066              Inception  2010
# 1  tt1345836         8.4          1387769  The Dark Knight Rises  2012
# 2  tt0816692         8.6          1299334           Interstellar  2014
# 3  tt1853728         8.4          1211405       Django Unchained  2012
# 4  tt0848228         8.1          1183655           The Avengers  2012
#
#    Minutes                   Genres
# 0    148.0  Action,Adventure,Sci-Fi
# 1    164.0          Action,Thriller
# 2    169.0   Adventure,Drama,Sci-Fi
# 3    165.0            Drama,Western
# 4    143.0  Action,Adventure,Sci-Fi

# %%
pd.read_sql("""
SELECT MOVIE_ID AS Movie_ID, AVERAGERATING AS Avg_Rating, NUMVOTES AS Number_of_Votes, PERSON_ID AS Person_ID, CATEGORY AS Profession
FROM MOVIE_RATINGS
JOIN PRINCIPALS
    USING(MOVIE_ID)
WHERE NUMVOTES > 15000
ORDER BY NUMVOTES DESC
;
""", conn)
# Out:
#         Movie_ID  Avg_Rating  Number_of_Votes  Person_ID           Profession
# 0      tt1375666         8.8          1841066  nm0000138                actor
# 1      tt1375666         8.8          1841066  nm0001877             composer
# 2      tt1375666         8.8          1841066  nm0002892      cinematographer
# 3      tt1375666         8.8          1841066  nm0245596  production_designer
# 4      tt1375666         8.8          1841066  nm0330687                actor
# ...          ...         ...              ...        ...                  ...
# 21491  tt1434435         6.3            15012  nm0500329               writer
# 21492  tt1434435         6.3            15012  nm0711840             producer
# 21493  tt1434435         6.3            15012  nm0764552             producer
# 21494  tt1434435         6.3            15012  nm1135423             director
# 21495  tt1434435         6.3            15012  nm1556126               writer
#
# [21496 rows x 5 columns]

# %%
pd.read_sql("""
SELECT MOVIE_ID AS Movie_ID, PERSON_ID AS Person_ID, CATEGORY AS Profession, PRIMARY_NAME AS Name
FROM PERSONS
JOIN PRINCIPALS
    USING(PERSON_ID)
;
""", conn)
# Out:
#           Movie_ID  Person_ID Profession                 Name
# 0        tt2398241  nm0061671   producer    Mary Ellen Bauder
# 1        tt0433397  nm0061865   composer         Joseph Bauer
# 2        tt1681372  nm0061865   composer         Joseph Bauer
# 3        tt2281215  nm0061865   composer         Joseph Bauer
# 4        tt2387710  nm0061865   composer         Joseph Bauer
# ...            ...        ...        ...                  ...
# 1027907  tt6527982  nm9990381    actress         Susan Grobes
# 1027908  tt8737130  nm9990690    actress          Joo Yeon So
# 1027909  tt8734436  nm9991320    actress       Madeline Smith
# 1027910  tt8739240  nm9991786   producer  Michelle Modigliani
# 1027911  tt8743182  nm9993380   director       Pegasus Envoyé
#
# [1027912 rows x 4 columns]

# %%
imdb_important_data = pd.read_sql("""
SELECT Distinct primary_title as Title, averagerating as IMDB_Rating, runtime_minutes as Runtime, start_year as Year, genres as Genres
FROM MOVIE_RATINGS
JOIN MOVIE_BASICS
    USING(MOVIE_ID)
JOIN MOVIE_AKAS
    USING(MOVIE_ID)
WHERE numvotes > 5000 and region == "US"
ORDER BY averagerating DESC
;
""", conn)

# %%
imdb_important_data
# Out:
#                                   Title  IMDB_Rating  Runtime  Year  \
# 0     Once Upon a Time ... in Hollywood          9.7    159.0  2019
# 1                               Peranbu          9.4    147.0  2018
# 2                                Wheels          9.3    115.0  2014
# 3                 O.J.: Made in America          8.9    467.0  2016
# 4                             Inception          8.8    148.0  2010
# ...                                 ...          ...      ...   ...
# 2764                         Himmatwala          1.7    150.0  2013
# 2765     Justin Bieber: Never Say Never          1.6    105.0  2011
# 2766                  Code Name: K.O.Z.          1.5    114.0  2015
# 2767                   Saving Christmas          1.5     79.0  2014
# 2768                       Potato Salad          1.3     81.0  2015
#
#                            Genres
# 0                    Comedy,Drama
# 1                           Drama
# 2                           Drama
# 3     Biography,Crime,Documentary
# 4         Action,Adventure,Sci-Fi
# ...                           ...
# 2764          Action,Comedy,Drama
# 2765            Documentary,Music
# 2766                Crime,Mystery
# 2767                Comedy,Family
# 2768                Comedy,Horror
#
# [2769 rows x 5 columns]

# %%
imdb_clean_table = pd.read_sql("""
SELECT DISTINCT PRIMARY_TITLE AS Title, AVERAGERATING AS Rating, START_YEAR AS Year, RUNTIME_MINUTES AS Runtime, GENRES AS Genres
FROM MOVIE_RATINGS
JOIN MOVIE_BASICS
    USING(MOVIE_ID)
JOIN MOVIE_AKAS
    USING(MOVIE_ID)
WHERE numvotes > 5000
ORDER BY averagerating DESC
;
""", conn)

imdb_clean_table
# Out:
#                                   Title  Rating  Year  Runtime  \
# 0     Once Upon a Time ... in Hollywood     9.7  2019    159.0
# 1                         Aloko Udapadi     9.5  2017    113.0
# 2                               Peranbu     9.4  2018    147.0
# 3                       The Mountain II     9.3  2016    135.0
# 4                              Aynabaji     9.3  2016    147.0
# ...                                 ...     ...   ...      ...
# 3913                   Saving Christmas     1.5  2014     79.0
# 3914                  Code Name: K.O.Z.     1.5  2015    114.0
# 3915                           Smolensk     1.4  2016    120.0
# 3916                       Potato Salad     1.3  2015     81.0
# 3917     Cumali Ceber: Allah Seni Alsin     1.3  2017    100.0
#
#                       Genres
# 0               Comedy,Drama
# 1              Drama,History
# 2                      Drama
# 3           Action,Drama,War
# 4     Crime,Mystery,Thriller
# ...                      ...
# 3913           Comedy,Family
# 3914           Crime,Mystery
# 3915          Drama,Thriller
# 3916           Comedy,Horror
# 3917                  Comedy
#
# [3918 rows x 5 columns]

# %% [markdown]
# ## TMDB x Movie Gross (Trase, Karl, and Mark)

# %%
movie_gross_df = pd.read_csv('../../zippedData/bom.movie_gross.csv.gz')

# %%
tmdb_df = pd.read_csv('../../zippedData/tmdb.movies.csv.gz')

# %%
movie_budgets_df = pd.read_csv('../../zippedData/tn.movie_budgets.csv.gz')

# %%
movie_budgets_df['production_budget'] = movie_budgets_df['production_budget'].str.replace(',', '').str.replace('$', '').astype('float')
movie_budgets_df['domestic_gross'] = movie_budgets_df['domestic_gross'].str.replace(',', '').str.replace('$', '').astype('float')
movie_budgets_df['worldwide_gross'] = movie_budgets_df['worldwide_gross'].str.replace(',', '').str.replace('$', '').astype('float')

# %%
# Calculate the profit and add it as a new column to the movie budgets dataframe
movie_budgets_df['profit'] = movie_budgets_df['worldwide_gross'] - movie_budgets_df['production_budget']

# Sort the dataframe by the profit column in descending order to see the most successful movies
most_profitable_movies = movie_budgets_df.sort_values('profit', ascending=False)

# %%
merged_df = movie_gross_df.merge(movie_budgets_df, how='right', left_on='title', right_on='movie')

# %%
merged_tmdb_budget = movie_budgets_df.merge(tmdb_df, how='inner', left_on='movie', right_on='title')

# %%
new_merged = merged_tmdb_budget.drop(['original_title'], axis=1)

# %%
karl_carolyn_merge = new_merged.drop(['id_x','release_date_x','genre_ids','id_y','Unnamed: 0'], axis=1)

# %%
# Creating Quarter Column
karl_carolyn_merge['release_date_y'] = pd.to_datetime(karl_carolyn_merge['release_date_y'])

karl_carolyn_merge['Quarter'] = karl_carolyn_merge['release_date_y'].dt.to_period('Q')

# %%
karl_carolyn_merge.rename(columns = {'movie':'Title'},inplace = True)

# %%
karl_carolyn_merge.rename(columns = {'profit':'Profit'},inplace = True)

# %%
karl_carolyn_merge.rename(columns = {'release_date_y':'Release_Date'},inplace = True)

# %%
karl_carolyn_merge.rename(columns = {'production_budget':'Production_Budget'},inplace = True)

# %%
karl_carolyn_merge.rename(columns = {'domestic_gross':'Domestic_Gross'},inplace = True)

# %%
karl_carolyn_merge.rename(columns = {'worldwide_gross':'Worldwide_Gross'},inplace = True)

# %%
karl_carolyn_merge.rename(columns = {'original_language':'Original_Language'},inplace = True)

# %%
karl_carolyn_merge.rename(columns = {'popularity':'Popularity'},inplace = True)

# %%
karl_carolyn_merge.rename(columns = {'vote_average':'TMDB_Rating'},inplace = True)

# %%
karl_carolyn_merge.rename(columns = {'vote_count':'Vote_Count'},inplace = True)

# %%
karl_carolyn_merge = karl_carolyn_merge.drop(['title'], axis=1)
karl_carolyn_merge
# Out:
#                                             Title  Production_Budget  \
# 0                                          Avatar        425000000.0
# 1     Pirates of the Caribbean: On Stranger Tides        410600000.0
# 2                         Avengers: Age of Ultron        330600000.0
# 3                          Avengers: Infinity War        300000000.0
# 4                                  Justice League        300000000.0
# ...                                           ...                ...
# 2380                                       Exeter            25000.0
# 2381                                          Ten            25000.0
# 2382                                    Dry Spell            22000.0
# 2383                     All Superheroes Must Die            20000.0
# 2384                                    Newlyweds             9000.0
#
#       Domestic_Gross  Worldwide_Gross        Profit Original_Language  \
# 0        760507625.0     2.776345e+09  2.351345e+09                en
# 1        241063875.0     1.045664e+09  6.350639e+08                en
# 2        459005868.0     1.403014e+09  1.072414e+09                en
# 3        678815482.0     2.048134e+09  1.748134e+09                en
# 4        229024295.0     6.559452e+08  3.559452e+08                en
# ...              ...              ...           ...               ...
# 2380             0.0     4.897920e+05  4.647920e+05                en
# 2381             0.0     0.000000e+00 -2.500000e+04                en
# 2382             0.0     0.000000e+00 -2.200000e+04                en
# 2383             0.0     0.000000e+00 -2.000000e+04                en
# 2384          4584.0     4.584000e+03 -4.416000e+03                en
#
#       Popularity Release_Date  TMDB_Rating  Vote_Count Quarter
# 0         26.526   2009-12-18          7.4       18676  2009Q4
# 1         30.579   2011-05-20          6.4        8571  2011Q2
# 2         44.383   2015-05-01          7.3       13457  2015Q2
# 3         80.773   2018-04-27          8.3       13948  2018Q2
# 4         34.953   2017-11-17          6.2        7510  2017Q4
# ...          ...          ...          ...         ...     ...
# 2380       5.934   2015-03-26          4.7         121  2015Q1
# 2381       1.575   2014-03-28          5.4           5  2014Q1
# 2382       0.600   2013-02-14          6.0           1  2013Q1
# 2383       2.078   2013-01-04          3.9          19  2013Q1
# 2384       1.973   2011-12-26          5.4           7  2011Q4
#
# [2385 rows x 11 columns]

# %% [markdown]
# ## Quarter Column & Cleaning (Trase, Karl, Mark, Al Ameen, Carolyn)

# %%
# Created new column with Quarter column values as a string
karl_carolyn_merge['Q'] = karl_carolyn_merge['Quarter'].astype(str)
karl_carolyn_merge['Q']
# Out:
# 0       2009Q4
# 1       2011Q2
# 2       2015Q2
# 3       2018Q2
# 4       2017Q4
#          ...
# 2380    2015Q1
# 2381    2014Q1
# 2382    2013Q1
# 2383    2013Q1
# 2384    2011Q4
# Name: Q, Length: 2385, dtype: object

# %%
# Creating a quarter of year column
karl_carolyn_merge['s'] = karl_carolyn_merge['Q'].map( lambda x: x[-1:])
karl_carolyn_merge['s']
# Out:
# 0       4
# 1       2
# 2       2
# 3       2
# 4       4
#        ..
# 2380    1
# 2381    1
# 2382    1
# 2383    1
# 2384    4
# Name: s, Length: 2385, dtype: object

# %%
karl_carolyn_merge['Vote_Count'].unique
# Out:
# <bound method Series.unique of 0       18676
# 1        8571
# 2       13457
# 3       13948
# 4        7510
#         ...
# 2380      121
# 2381        5
# 2382        1
# 2383       19
# 2384        7
# Name: Vote_Count, Length: 2385, dtype: int64>

# %%
karl_carolyn_merge2 = karl_carolyn_merge

# %%
# Drops rows with less than 5 votes for ratings
karl_carolyn_merge2.drop(karl_carolyn_merge2[karl_carolyn_merge2.Vote_Count < 5].index, inplace=True)

# %%
#karl_carolyn_merge2 = karl_carolyn_merge2.drop(['Quarter'], axis=1)
karl_carolyn_merge2
# Out:
#                                             Title  Production_Budget  \
# 0                                          Avatar        425000000.0
# 1     Pirates of the Caribbean: On Stranger Tides        410600000.0
# 2                         Avengers: Age of Ultron        330600000.0
# 3                          Avengers: Infinity War        300000000.0
# 4                                  Justice League        300000000.0
# ...                                           ...                ...
# 2378                                       Krisha            30000.0
# 2380                                       Exeter            25000.0
# 2381                                          Ten            25000.0
# 2383                     All Superheroes Must Die            20000.0
# 2384                                    Newlyweds             9000.0
#
#       Domestic_Gross  Worldwide_Gross        Profit Original_Language  \
# 0        760507625.0     2.776345e+09  2.351345e+09                en
# 1        241063875.0     1.045664e+09  6.350639e+08                en
# 2        459005868.0     1.403014e+09  1.072414e+09                en
# 3        678815482.0     2.048134e+09  1.748134e+09                en
# 4        229024295.0     6.559452e+08  3.559452e+08                en
# ...              ...              ...           ...               ...
# 2378        144822.0     1.448220e+05  1.148220e+05                en
# 2380             0.0     4.897920e+05  4.647920e+05                en
# 2381             0.0     0.000000e+00 -2.500000e+04                en
# 2383             0.0     0.000000e+00 -2.000000e+04                en
# 2384          4584.0     4.584000e+03 -4.416000e+03                en
#
#       Popularity Release_Date  TMDB_Rating  Vote_Count Quarter       Q  s
# 0         26.526   2009-12-18          7.4       18676  2009Q4  2009Q4  4
# 1         30.579   2011-05-20          6.4        8571  2011Q2  2011Q2  2
# 2         44.383   2015-05-01          7.3       13457  2015Q2  2015Q2  2
# 3         80.773   2018-04-27          8.3       13948  2018Q2  2018Q2  2
# 4         34.953   2017-11-17          6.2        7510  2017Q4  2017Q4  4
# ...          ...          ...          ...         ...     ...     ... ..
# 2378       5.288   2016-03-18          6.8          86  2016Q1  2016Q1  1
# 2380       5.934   2015-03-26          4.7         121  2015Q1  2015Q1  1
# 2381       1.575   2014-03-28          5.4           5  2014Q1  2014Q1  1
# 2383       2.078   2013-01-04          3.9          19  2013Q1  2013Q1  1
# 2384       1.973   2011-12-26          5.4           7  2011Q4  2011Q4  4
#
# [2094 rows x 13 columns]

# %%
# Renaming Column
karl_carolyn_merge2.rename(columns = {'s':'Quarter_Num'},inplace = True)

# %%
#Creating Year Column
karl_carolyn_merge2['Year'] = karl_carolyn_merge2['Q'].map( lambda x: x[:4])

# %%
# Dropping Column Q
karl_carolyn_merge2 = karl_carolyn_merge2.drop(['Q'], axis=1)

# %%
karl_carolyn_merge2 = karl_carolyn_merge2.drop(['Quarter'], axis=1)

# %%
# Dropping Release Date
karl_carolyn_merge2 = karl_carolyn_merge2.drop(['Release_Date'], axis=1)
karl_carolyn_merge2
# Out:
#                                             Title  Production_Budget  \
# 0                                          Avatar        425000000.0
# 1     Pirates of the Caribbean: On Stranger Tides        410600000.0
# 2                         Avengers: Age of Ultron        330600000.0
# 3                          Avengers: Infinity War        300000000.0
# 4                                  Justice League        300000000.0
# ...                                           ...                ...
# 2378                                       Krisha            30000.0
# 2380                                       Exeter            25000.0
# 2381                                          Ten            25000.0
# 2383                     All Superheroes Must Die            20000.0
# 2384                                    Newlyweds             9000.0
#
#       Domestic_Gross  Worldwide_Gross        Profit Original_Language  \
# 0        760507625.0     2.776345e+09  2.351345e+09                en
# 1        241063875.0     1.045664e+09  6.350639e+08                en
# 2        459005868.0     1.403014e+09  1.072414e+09                en
# 3        678815482.0     2.048134e+09  1.748134e+09                en
# 4        229024295.0     6.559452e+08  3.559452e+08                en
# ...              ...              ...           ...               ...
# 2378        144822.0     1.448220e+05  1.148220e+05                en
# 2380             0.0     4.897920e+05  4.647920e+05                en
# 2381             0.0     0.000000e+00 -2.500000e+04                en
# 2383             0.0     0.000000e+00 -2.000000e+04                en
# 2384          4584.0     4.584000e+03 -4.416000e+03                en
#
#       Popularity  TMDB_Rating  Vote_Count Quarter_Num  Year
# 0         26.526          7.4       18676           4  2009
# 1         30.579          6.4        8571           2  2011
# 2         44.383          7.3       13457           2  2015
# 3         80.773          8.3       13948           2  2018
# 4         34.953          6.2        7510           4  2017
# ...          ...          ...         ...         ...   ...
# 2378       5.288          6.8          86           1  2016
# 2380       5.934          4.7         121           1  2015
# 2381       1.575          5.4           5           1  2014
# 2383       2.078          3.9          19           1  2013
# 2384       1.973          5.4           7           4  2011
#
# [2094 rows x 11 columns]

# %% [markdown]
# ## Final Dataset (Trase)

# %%
# Merging karl_carolyn_merge2 with imdb_clean_table

final_dataset = karl_carolyn_merge2.merge(imdb_clean_table, how='left', left_on='Title', right_on='Title')
final_dataset
# Out:
#                                             Title  Production_Budget  \
# 0                                          Avatar        425000000.0
# 1     Pirates of the Caribbean: On Stranger Tides        410600000.0
# 2                         Avengers: Age of Ultron        330600000.0
# 3                          Avengers: Infinity War        300000000.0
# 4                                  Justice League        300000000.0
# ...                                           ...                ...
# 2120                                       Krisha            30000.0
# 2121                                       Exeter            25000.0
# 2122                                          Ten            25000.0
# 2123                     All Superheroes Must Die            20000.0
# 2124                                    Newlyweds             9000.0
#
#       Domestic_Gross  Worldwide_Gross        Profit Original_Language  \
# 0        760507625.0     2.776345e+09  2.351345e+09                en
# 1        241063875.0     1.045664e+09  6.350639e+08                en
# 2        459005868.0     1.403014e+09  1.072414e+09                en
# 3        678815482.0     2.048134e+09  1.748134e+09                en
# 4        229024295.0     6.559452e+08  3.559452e+08                en
# ...              ...              ...           ...               ...
# 2120        144822.0     1.448220e+05  1.148220e+05                en
# 2121             0.0     4.897920e+05  4.647920e+05                en
# 2122             0.0     0.000000e+00 -2.500000e+04                en
# 2123             0.0     0.000000e+00 -2.000000e+04                en
# 2124          4584.0     4.584000e+03 -4.416000e+03                en
#
#       Popularity  TMDB_Rating  Vote_Count Quarter_Num Year_x  Rating  Year_y  \
# 0         26.526          7.4       18676           4   2009     NaN     NaN
# 1         30.579          6.4        8571           2   2011     6.6  2011.0
# 2         44.383          7.3       13457           2   2015     7.3  2015.0
# 3         80.773          8.3       13948           2   2018     8.5  2018.0
# 4         34.953          6.2        7510           4   2017     6.5  2017.0
# ...          ...          ...         ...         ...    ...     ...     ...
# 2120       5.288          6.8          86           1   2016     7.2  2015.0
# 2121       5.934          4.7         121           1   2015     4.5  2015.0
# 2122       1.575          5.4           5           1   2014     NaN     NaN
# 2123       2.078          3.9          19           1   2013     NaN     NaN
# 2124       1.973          5.4           7           4   2011     NaN     NaN
#
#       Runtime                    Genres
# 0         NaN                       NaN
# 1       136.0  Action,Adventure,Fantasy
# 2       141.0   Action,Adventure,Sci-Fi
# 3       149.0   Action,Adventure,Sci-Fi
# 4       120.0  Action,Adventure,Fantasy
# ...       ...                       ...
# 2120     83.0                     Drama
# 2121     91.0   Horror,Mystery,Thriller
# 2122      NaN                       NaN
# 2123      NaN                       NaN
# 2124      NaN                       NaN
#
# [2125 rows x 15 columns]

# %%
final_dataset['Runtime'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         NaN
# 1       136.0
# 2       141.0
# 3       149.0
# 4       120.0
#         ...
# 2120     83.0
# 2121     91.0
# 2122      NaN
# 2123      NaN
# 2124      NaN
# Name: Runtime, Length: 2125, dtype: float64>

# %%
final_dataset['Rating'].isnull().sum()
# Out:
# 405

# %%
#final_dataset['Genres'].astype(str)

# %%
final_dataset2 = final_dataset.dropna(how="any",axis = 0)
final_dataset2
# Out:
#                                             Title  Production_Budget  \
# 1     Pirates of the Caribbean: On Stranger Tides        410600000.0
# 2                         Avengers: Age of Ultron        330600000.0
# 3                          Avengers: Infinity War        300000000.0
# 4                                  Justice League        300000000.0
# 5                                  Justice League        300000000.0
# ...                                           ...                ...
# 2114                                  The Dirties            55000.0
# 2115                               Tiny Furniture            50000.0
# 2119                                       Krisha            30000.0
# 2120                                       Krisha            30000.0
# 2121                                       Exeter            25000.0
#
#       Domestic_Gross  Worldwide_Gross        Profit Original_Language  \
# 1        241063875.0     1.045664e+09  6.350639e+08                en
# 2        459005868.0     1.403014e+09  1.072414e+09                en
# 3        678815482.0     2.048134e+09  1.748134e+09                en
# 4        229024295.0     6.559452e+08  3.559452e+08                en
# 5        229024295.0     6.559452e+08  3.559452e+08                en
# ...              ...              ...           ...               ...
# 2114             0.0     0.000000e+00 -5.500000e+04                en
# 2115        391674.0     4.241490e+05  3.741490e+05                en
# 2119        144822.0     1.448220e+05  1.148220e+05                en
# 2120        144822.0     1.448220e+05  1.148220e+05                en
# 2121             0.0     4.897920e+05  4.647920e+05                en
#
#       Popularity  TMDB_Rating  Vote_Count Quarter_Num Year_x  Rating  Year_y  \
# 1         30.579          6.4        8571           2   2011     6.6  2011.0
# 2         44.383          7.3       13457           2   2015     7.3  2015.0
# 3         80.773          8.3       13948           2   2018     8.5  2018.0
# 4         34.953          6.2        7510           4   2017     6.5  2017.0
# 5         34.953          6.2        7510           4   2017     6.5  2017.0
# ...          ...          ...         ...         ...    ...     ...     ...
# 2114       2.971          6.1          57           4   2013     6.8  2013.0
# 2115       6.695          5.9          82           4   2010     6.2  2010.0
# 2119       5.288          6.8          86           1   2016     7.2  2015.0
# 2120       5.288          6.8          86           1   2016     7.2  2015.0
# 2121       5.934          4.7         121           1   2015     4.5  2015.0
#
#       Runtime                    Genres
# 1       136.0  Action,Adventure,Fantasy
# 2       141.0   Action,Adventure,Sci-Fi
# 3       149.0   Action,Adventure,Sci-Fi
# 4       120.0  Action,Adventure,Fantasy
# 5       120.0  Action,Adventure,Fantasy
# ...       ...                       ...
# 2114     83.0               Crime,Drama
# 2115     98.0      Comedy,Drama,Romance
# 2119     83.0                     Drama
# 2120     83.0                     Drama
# 2121     91.0   Horror,Mystery,Thriller
#
# [1720 rows x 15 columns]

# %%
#final_dataset["Genres"] = final_dataset["Genres"].str.split(",").apply(lambda x: [i.strip() for i in x])
#final_dataset
final_dataset2['Genre'] = final_dataset2['Genres'].map( lambda x: x[:4])
final_dataset2

#dfmi.loc[:, ('one', 'second')]
# Out:
# <ipython-input-47-486c4d24bb3d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_dataset2['Genre'] = final_dataset2['Genres'].map( lambda x: x[:4])
#                                             Title  Production_Budget  \
# 1     Pirates of the Caribbean: On Stranger Tides        410600000.0
# 2                         Avengers: Age of Ultron        330600000.0
# 3                          Avengers: Infinity War        300000000.0
# 4                                  Justice League        300000000.0
# 5                                  Justice League        300000000.0
# ...                                           ...                ...
# 2114                                  The Dirties            55000.0
# 2115                               Tiny Furniture            50000.0
# 2119                                       Krisha            30000.0
# 2120                                       Krisha            30000.0
# 2121                                       Exeter            25000.0
#
#       Domestic_Gross  Worldwide_Gross        Profit Original_Language  \
# 1        241063875.0     1.045664e+09  6.350639e+08                en
# 2        459005868.0     1.403014e+09  1.072414e+09                en
# 3        678815482.0     2.048134e+09  1.748134e+09                en
# 4        229024295.0     6.559452e+08  3.559452e+08                en
# 5        229024295.0     6.559452e+08  3.559452e+08                en
# ...              ...              ...           ...               ...
# 2114             0.0     0.000000e+00 -5.500000e+04                en
# 2115        391674.0     4.241490e+05  3.741490e+05                en
# 2119        144822.0     1.448220e+05  1.148220e+05                en
# 2120        144822.0     1.448220e+05  1.148220e+05                en
# 2121             0.0     4.897920e+05  4.647920e+05                en
#
#       Popularity  TMDB_Rating  Vote_Count Quarter_Num Year_x  Rating  Year_y  \
# 1         30.579          6.4        8571           2   2011     6.6  2011.0
# 2         44.383          7.3       13457           2   2015     7.3  2015.0
# 3         80.773          8.3       13948           2   2018     8.5  2018.0
# 4         34.953          6.2        7510           4   2017     6.5  2017.0
# 5         34.953          6.2        7510           4   2017     6.5  2017.0
# ...          ...          ...         ...         ...    ...     ...     ...
# 2114       2.971          6.1          57           4   2013     6.8  2013.0
# 2115       6.695          5.9          82           4   2010     6.2  2010.0
# 2119       5.288          6.8          86           1   2016     7.2  2015.0
# 2120       5.288          6.8          86           1   2016     7.2  2015.0
# 2121       5.934          4.7         121           1   2015     4.5  2015.0
#
#       Runtime                    Genres Genre
# 1       136.0  Action,Adventure,Fantasy  Acti
# 2       141.0   Action,Adventure,Sci-Fi  Acti
# 3       149.0   Action,Adventure,Sci-Fi  Acti
# 4       120.0  Action,Adventure,Fantasy  Acti
# 5       120.0  Action,Adventure,Fantasy  Acti
# ...       ...                       ...   ...
# 2114     83.0               Crime,Drama  Crim
# 2115     98.0      Comedy,Drama,Romance  Come
# 2119     83.0                     Drama  Dram
# 2120     83.0                     Drama  Dram
# 2121     91.0   Horror,Mystery,Thriller  Horr
#
# [1720 rows x 16 columns]

# %%
final_dataset2.rename(columns = {'Rating':'IMDB_Rating'},inplace = True)
# Out:
# C:\Users\tjester\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
final_dataset2 = final_dataset2.drop(['Year_y'], axis=1)

# %%
final_dataset2
# Out:
#                                             Title  Production_Budget  \
# 1     Pirates of the Caribbean: On Stranger Tides        410600000.0
# 2                         Avengers: Age of Ultron        330600000.0
# 3                          Avengers: Infinity War        300000000.0
# 4                                  Justice League        300000000.0
# 5                                  Justice League        300000000.0
# ...                                           ...                ...
# 2114                                  The Dirties            55000.0
# 2115                               Tiny Furniture            50000.0
# 2119                                       Krisha            30000.0
# 2120                                       Krisha            30000.0
# 2121                                       Exeter            25000.0
#
#       Domestic_Gross  Worldwide_Gross        Profit Original_Language  \
# 1        241063875.0     1.045664e+09  6.350639e+08                en
# 2        459005868.0     1.403014e+09  1.072414e+09                en
# 3        678815482.0     2.048134e+09  1.748134e+09                en
# 4        229024295.0     6.559452e+08  3.559452e+08                en
# 5        229024295.0     6.559452e+08  3.559452e+08                en
# ...              ...              ...           ...               ...
# 2114             0.0     0.000000e+00 -5.500000e+04                en
# 2115        391674.0     4.241490e+05  3.741490e+05                en
# 2119        144822.0     1.448220e+05  1.148220e+05                en
# 2120        144822.0     1.448220e+05  1.148220e+05                en
# 2121             0.0     4.897920e+05  4.647920e+05                en
#
#       Popularity  TMDB_Rating  Vote_Count Quarter_Num Year_x  IMDB_Rating  \
# 1         30.579          6.4        8571           2   2011          6.6
# 2         44.383          7.3       13457           2   2015          7.3
# 3         80.773          8.3       13948           2   2018          8.5
# 4         34.953          6.2        7510           4   2017          6.5
# 5         34.953          6.2        7510           4   2017          6.5
# ...          ...          ...         ...         ...    ...          ...
# 2114       2.971          6.1          57           4   2013          6.8
# 2115       6.695          5.9          82           4   2010          6.2
# 2119       5.288          6.8          86           1   2016          7.2
# 2120       5.288          6.8          86           1   2016          7.2
# 2121       5.934          4.7         121           1   2015          4.5
#
#       Runtime                    Genres Genre
# 1       136.0  Action,Adventure,Fantasy  Acti
# 2       141.0   Action,Adventure,Sci-Fi  Acti
# 3       149.0   Action,Adventure,Sci-Fi  Acti
# 4       120.0  Action,Adventure,Fantasy  Acti
# 5       120.0  Action,Adventure,Fantasy  Acti
# ...       ...                       ...   ...
# 2114     83.0               Crime,Drama  Crim
# 2115     98.0      Comedy,Drama,Romance  Come
# 2119     83.0                     Drama  Dram
# 2120     83.0                     Drama  Dram
# 2121     91.0   Horror,Mystery,Thriller  Horr
#
# [1720 rows x 15 columns]

# %%
final_dataset2.rename(columns = {'Year_x':'Year'},inplace = True)

# %%
final_dataset2 = final_dataset2.drop(['Genres'], axis=1)

# %%
final_dataset2
# Out:
#                                             Title  Production_Budget  \
# 1     Pirates of the Caribbean: On Stranger Tides        410600000.0
# 2                         Avengers: Age of Ultron        330600000.0
# 3                          Avengers: Infinity War        300000000.0
# 4                                  Justice League        300000000.0
# 5                                  Justice League        300000000.0
# ...                                           ...                ...
# 2114                                  The Dirties            55000.0
# 2115                               Tiny Furniture            50000.0
# 2119                                       Krisha            30000.0
# 2120                                       Krisha            30000.0
# 2121                                       Exeter            25000.0
#
#       Domestic_Gross  Worldwide_Gross        Profit Original_Language  \
# 1        241063875.0     1.045664e+09  6.350639e+08                en
# 2        459005868.0     1.403014e+09  1.072414e+09                en
# 3        678815482.0     2.048134e+09  1.748134e+09                en
# 4        229024295.0     6.559452e+08  3.559452e+08                en
# 5        229024295.0     6.559452e+08  3.559452e+08                en
# ...              ...              ...           ...               ...
# 2114             0.0     0.000000e+00 -5.500000e+04                en
# 2115        391674.0     4.241490e+05  3.741490e+05                en
# 2119        144822.0     1.448220e+05  1.148220e+05                en
# 2120        144822.0     1.448220e+05  1.148220e+05                en
# 2121             0.0     4.897920e+05  4.647920e+05                en
#
#       Popularity  TMDB_Rating  Vote_Count Quarter_Num  Year  IMDB_Rating  \
# 1         30.579          6.4        8571           2  2011          6.6
# 2         44.383          7.3       13457           2  2015          7.3
# 3         80.773          8.3       13948           2  2018          8.5
# 4         34.953          6.2        7510           4  2017          6.5
# 5         34.953          6.2        7510           4  2017          6.5
# ...          ...          ...         ...         ...   ...          ...
# 2114       2.971          6.1          57           4  2013          6.8
# 2115       6.695          5.9          82           4  2010          6.2
# 2119       5.288          6.8          86           1  2016          7.2
# 2120       5.288          6.8          86           1  2016          7.2
# 2121       5.934          4.7         121           1  2015          4.5
#
#       Runtime Genre
# 1       136.0  Acti
# 2       141.0  Acti
# 3       149.0  Acti
# 4       120.0  Acti
# 5       120.0  Acti
# ...       ...   ...
# 2114     83.0  Crim
# 2115     98.0  Come
# 2119     83.0  Dram
# 2120     83.0  Dram
# 2121     91.0  Horr
#
# [1720 rows x 14 columns]

# %% [markdown]
# ## Final Dataset Visualizations (Trase, Karl, & Al Ameen)

# %%
import numpy as np
avg_profit_by_qtr = final_dataset2.groupby("Quarter_Num")["Profit"].mean()
profit_by_qrt_array = np.array(avg_profit_by_qtr)
profit_by_qrt_array
# Out:
# array([9.73605912e+07, 1.37937438e+08, 8.76049270e+07, 1.02897389e+08])

# %%
# Created Bar Chart for Top Quarters by Profit 
x1 = ['Q1','Q2','Q3','Q4']
a1 = profit_by_qrt_array

sns.barplot(x1,a1)
plt.title('Top Quarters by Profit')
plt.xlabel('Quarters')
plt.ylabel('Average Profit $ (in billions)')
plt.show()
# Out:
# C:\Users\tjester\Anaconda3\envs\learn-env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
count_by_qtr = final_dataset2['Quarter_Num'].value_counts()
count_by_qtr
count_by_qtr_array = np.array(count_by_qtr)

# %%
x1 = ['Q1','Q2','Q3','Q4']
a1 = count_by_qtr_array

sns.barplot(x1,a1)
plt.title('Count of Films Released by Quarter')
plt.xlabel('Quarter')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\tjester\Anaconda3\envs\learn-env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
avg_profit_by_genre = final_dataset2.groupby("Genre")["Profit"].mean()
profit_by_genre_array = np.array(avg_profit_by_genre)
profit_by_genre_array
# Out:
# array([1.69166333e+08, 2.13467561e+08, 2.17096773e+08, 4.87156787e+07,
#        4.27771092e+07, 3.34916067e+07, 6.05960869e+06, 5.83762228e+07,
#        8.43815419e+08, 2.69261404e+07, 7.12348993e+07, 1.10999889e+08,
#        7.67313250e+07])

# %%
final_dataset2 = final_dataset2.sort_values(by = "Profit",ascending = False)
final_dataset2
# Out:
#                       Title  Production_Budget  Domestic_Gross  \
# 3    Avengers: Infinity War        300000000.0     678815482.0
# 26           Jurassic World        215000000.0     652270625.0
# 59                Furious 7        190000000.0     353007020.0
# 20             The Avengers        225000000.0     623279547.0
# 38            Black Panther        200000000.0     700059566.0
# ..                      ...                ...             ...
# 228          Monster Trucks        125000000.0      33370166.0
# 334             The Promise         90000000.0       8224288.0
# 333             The Promise         90000000.0       8224288.0
# 336                  Bright         90000000.0             0.0
# 163         Mars Needs Moms        150000000.0      21392758.0
#
#      Worldwide_Gross        Profit Original_Language  Popularity  TMDB_Rating  \
# 3       2.048134e+09  1.748134e+09                en      80.773          8.3
# 26      1.648855e+09  1.433855e+09                en      20.709          6.6
# 59      1.518723e+09  1.328723e+09                en      20.396          7.3
# 20      1.517936e+09  1.292936e+09                en      50.289          7.6
# 38      1.348258e+09  1.148258e+09                en      44.140          7.4
# ..               ...           ...               ...         ...          ...
# 228     6.164280e+07 -6.335720e+07                en       8.827          5.9
# 334     1.055142e+07 -7.944858e+07                en      10.158          7.1
# 333     1.055142e+07 -7.944858e+07                en      10.158          7.1
# 336     0.000000e+00 -9.000000e+07                en      15.677          6.2
# 163     3.954976e+07 -1.104502e+08                en       8.852          5.7
#
#      Vote_Count Quarter_Num  Year  IMDB_Rating  Runtime Genre
# 3         13948           2  2018          8.5    149.0  Acti
# 26        14056           2  2015          7.0    124.0  Acti
# 59         6538           2  2015          7.2    137.0  Acti
# 20        19673           2  2012          8.1    143.0  Acti
# 38        12365           1  2018          7.3    134.0  Acti
# ..          ...         ...   ...          ...      ...   ...
# 228         414           1  2017          5.7    104.0  Acti
# 334         195           2  2017          6.1    133.0  Dram
# 333         195           2  2017          6.1    133.0  Dram
# 336        3181           4  2017          6.4    117.0  Acti
# 163         299           1  2011          5.4     88.0  Adve
#
# [1720 rows x 14 columns]

# %%
final_dataset2['Genre'].value_counts()
# Out:
# Acti    494
# Come    329
# Dram    301
# Adve    189
# Biog    150
# Horr    108
# Crim    105
# Docu     16
# Anim     11
# Fami      6
# Myst      5
# Fant      5
# Roma      1
# Name: Genre, dtype: int64

# %%
plt.figure(figsize=(25,10))
sns.barplot(x='Genre', y='Profit', data=final_dataset2)
plt.title('Top Genres by Profit')
plt.xlabel('Genres')
plt.ylabel('Profit $ (in billions)')
plt.show()

# %% [markdown]
# ## Testing (Al Ameen, Trase, and Karl)

# %%
final_dataset2.describe()
# Out:
#        Production_Budget  Domestic_Gross  Worldwide_Gross        Profit  \
# count       1.720000e+03    1.720000e+03     1.720000e+03  1.720000e+03
# mean        4.555180e+07    6.142915e+07     1.515925e+08  1.060407e+08
# std         5.537465e+07    9.172969e+07     2.442155e+08  2.044107e+08
# min         2.500000e+04    0.000000e+00     0.000000e+00 -1.104502e+08
# 25%         1.000000e+07    5.567743e+06     1.295811e+07 -2.157188e+05
# 50%         2.500000e+07    3.031311e+07     5.770557e+07  2.704369e+07
# 75%         5.800000e+07    7.301702e+07     1.704872e+08  1.152534e+08
# max         4.106000e+08    7.000596e+08     2.048134e+09  1.748134e+09
#
#         Popularity  TMDB_Rating    Vote_Count  IMDB_Rating      Runtime
# count  1720.000000  1720.000000   1720.000000  1720.000000  1720.000000
# mean     13.221893     6.355000   2215.271512     6.464477   109.193023
# std       7.863958     0.826586   2902.688273     0.923370    16.749010
# min       0.600000     2.100000      5.000000     1.600000    63.000000
# 25%       8.323000     5.800000    377.750000     5.900000    97.000000
# 50%      11.286000     6.300000   1101.000000     6.500000   106.000000
# 75%      15.974000     6.900000   2833.750000     7.100000   119.000000
# max      80.773000     8.400000  22186.000000     8.800000   180.000000

# %%
pop_mean= final_dataset2.Profit.mean()
pop_std = final_dataset2.Profit.std()

# %%
# Selecting a random sample
random_sample = final_dataset2.sample(n=100)
random_sample
# Out:
#                              Title  Production_Budget  Domestic_Gross  \
# 1683                   Rabbit Hole          5000000.0       2229058.0
# 1250                         Keanu         15000000.0      20591853.0
# 1974                Blue Valentine          1000000.0       9737892.0
# 688                     The Gunman         40000000.0      10664749.0
# 424                          Ted 2         68000000.0      81476385.0
# ...                            ...                ...             ...
# 364                      Smallfoot         80000000.0      83240103.0
# 976                My Soul to Take         25000000.0      14744435.0
# 1738                         Trust          4000000.0        120016.0
# 1795                   Please Give          3000000.0       4033574.0
# 216   Teenage Mutant Ninja Turtles         13500000.0     135265915.0
#
#       Worldwide_Gross       Profit Original_Language  Popularity  TMDB_Rating  \
# 1683        6205034.0    1205034.0                en       9.389          6.8
# 1250       20688141.0    5688141.0                en       8.952          6.0
# 1974       16566240.0   15566240.0                en       8.994          6.9
# 688        18594227.0  -21405773.0                en      10.388          5.7
# 424       217214143.0  149214143.0                en      17.684          6.1
# ...               ...          ...               ...         ...          ...
# 364       213691277.0  133691277.0                en      26.231          6.6
# 976        16727470.0   -8272530.0                en       9.808          5.4
# 1738         120016.0   -3879984.0                en       7.805          6.6
# 1795        4570178.0    1570178.0                en       5.945          6.3
# 216       202000000.0  188500000.0                en      25.619          5.8
#
#       Vote_Count Quarter_Num  Year  IMDB_Rating  Runtime Genre
# 1683         292           4  2010          7.0     91.0  Dram
# 1250         644           2  2016          6.3    100.0  Acti
# 1974        1677           4  2010          7.4    112.0  Dram
# 688          583           1  2015          5.8    115.0  Acti
# 424         4227           2  2015          6.3    115.0  Come
# ...          ...         ...   ...          ...      ...   ...
# 364          600           3  2018          6.7     96.0  Adve
# 976          247           4  2010          4.8    107.0  Horr
# 1738         556           2  2011          6.9    106.0  Crim
# 1795          81           1  2010          6.6     87.0  Come
# 216         4259           3  2014          5.8    101.0  Acti
#
# [100 rows x 14 columns]

# %%
sample_mean = random_sample.Profit.mean()
sample_std = random_sample.Profit.std()
print(sample_mean,sample_std)
print(pop_mean,pop_std)
# Out:
# 78111408.96 155073463.74150386
# 106040733.50465116 204410673.04747158

# %%
# H0 = sample_mean = 0
# H1 = sample_mean != 0

import scipy.stats as stats
from math import sqrt 

z = (sample_mean - pop_mean)/(pop_std / (sqrt(100)))
z

area_under = stats.norm.cdf(z)
print(area_under)
# Out:
# 0.0859170824420068

# %%
final_corr_matrix = final_dataset2.corr
print(final_corr_matrix)
# Out:
# <bound method DataFrame.corr of                       Title  Production_Budget  Domestic_Gross  \
# 3    Avengers: Infinity War        300000000.0     678815482.0
# 26           Jurassic World        215000000.0     652270625.0
# 59                Furious 7        190000000.0     353007020.0
# 20             The Avengers        225000000.0     623279547.0
# 38            Black Panther        200000000.0     700059566.0
# ..                      ...                ...             ...
# 228          Monster Trucks        125000000.0      33370166.0
# 334             The Promise         90000000.0       8224288.0
# 333             The Promise         90000000.0       8224288.0
# 336                  Bright         90000000.0             0.0
# 163         Mars Needs Moms        150000000.0      21392758.0
#
#      Worldwide_Gross        Profit Original_Language  Popularity  TMDB_Rating  \
# 3       2.048134e+09  1.748134e+09                en      80.773          8.3
# 26      1.648855e+09  1.433855e+09                en      20.709          6.6
# 59      1.518723e+09  1.328723e+09                en      20.396          7.3
# 20      1.517936e+09  1.292936e+09                en      50.289          7.6
# 38      1.348258e+09  1.148258e+09                en      44.140          7.4
# ..               ...           ...               ...         ...          ...
# 228     6.164280e+07 -6.335720e+07                en       8.827          5.9
# 334     1.055142e+07 -7.944858e+07                en      10.158          7.1
# 333     1.055142e+07 -7.944858e+07                en      10.158          7.1
# 336     0.000000e+00 -9.000000e+07                en      15.677          6.2
# 163     3.954976e+07 -1.104502e+08                en       8.852          5.7
#
#      Vote_Count Quarter_Num  Year  IMDB_Rating  Runtime Genre
# 3         13948           2  2018          8.5    149.0  Acti
# 26        14056           2  2015          7.0    124.0  Acti
# 59         6538           2  2015          7.2    137.0  Acti
# 20        19673           2  2012          8.1    143.0  Acti
# 38        12365           1  2018          7.3    134.0  Acti
# ..          ...         ...   ...          ...      ...   ...
# 228         414           1  2017          5.7    104.0  Acti
# 334         195           2  2017          6.1    133.0  Dram
# 333         195           2  2017          6.1    133.0  Dram
# 336        3181           4  2017          6.4    117.0  Acti
# 163         299           1  2011          5.4     88.0  Adve
#
# [1720 rows x 14 columns]>

# %%
import seaborn as sn
import matplotlib.pyplot as plt

sn.heatmap(final_corr_matrix, annot=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-e4750cd8e711> in <module>
#       2 import matplotlib.pyplot as plt
#       3
# ----> 4 sn.heatmap(final_corr_matrix, annot=True)
#       5 plt.show()
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\seaborn\matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     543     """
#     544     # Initialize the plotter object
# --> 545     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     546                           annot_kws, cbar, cbar_kws, xticklabels,
#     547                           yticklabels, mask)
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\seaborn\matrix.py in __init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     107         else:
#     108             plot_data = np.asarray(data)
# --> 109             data = pd.DataFrame(plot_data)
#     110
#     111         # Validate the mask and convet to DataFrame
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     495                 mgr = init_dict({data.name: data}, index, columns, dtype=dtype)
#     496             else:
# --> 497                 mgr = init_ndarray(data, index, columns, dtype=dtype, copy=copy)
#     498
#     499         # For data is list-like, or Iterable (will consume into list)
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\internals\construction.py in init_ndarray(values, index, columns, dtype, copy)
#     188     # by definition an array here
#     189     # the dtypes will be coerced to a single dtype
# --> 190     values = _prep_ndarray(values, copy=copy)
#     191
#     192     if dtype is not None:
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\internals\construction.py in _prep_ndarray(values, copy)
#     322         values = values.reshape((values.shape[0], 1))
#     323     elif values.ndim != 2:
# --> 324         raise ValueError(f"Must pass 2-d input. shape={values.shape}")
#     325
#     326     return values
#
# ValueError: Must pass 2-d input. shape=()

# %%
corr_pandg = final_dataset2['Profit'].corr(final_dataset2['Genre'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-4a4da189f0d6> in <module>
# ----> 1 corr_pandg = final_dataset2['Profit'].corr(final_dataset2['Genre'])
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\series.py in corr(self, other, method, min_periods)
#    2319
#    2320         if method in ["pearson", "spearman", "kendall"] or callable(method):
# -> 2321             return nanops.nancorr(
#    2322                 this.values, other.values, method=method, min_periods=min_periods
#    2323             )
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      69             try:
#      70                 with np.errstate(invalid="ignore"):
# ---> 71                     return f(*args, **kwargs)
#      72             except ValueError as e:
#      73                 # we want to transform an object array
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\nanops.py in nancorr(a, b, method, min_periods)
#    1350
#    1351     f = get_corr_func(method)
# -> 1352     return f(a, b)
#    1353
#    1354
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\nanops.py in func(a, b)
#    1371
#    1372         def func(a, b):
# -> 1373             return np.corrcoef(a, b)[0, 1]
#    1374
#    1375         return func
#
# <__array_function__ internals> in corrcoef(*args, **kwargs)
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\numpy\lib\function_base.py in corrcoef(x, y, rowvar, bias, ddof)
#    2524         warnings.warn('bias and ddof have no effect and are deprecated',
#    2525                       DeprecationWarning, stacklevel=3)
# -> 2526     c = cov(x, y, rowvar)
#    2527     try:
#    2528         d = diag(c)
#
# <__array_function__ internals> in cov(*args, **kwargs)
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\numpy\lib\function_base.py in cov(m, y, rowvar, bias, ddof, fweights, aweights)
#    2429             w *= aweights
#    2430
# -> 2431     avg, w_sum = average(X, axis=1, weights=w, returned=True)
#    2432     w_sum = w_sum[0]
#    2433
#
# <__array_function__ internals> in average(*args, **kwargs)
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\numpy\lib\function_base.py in average(a, axis, weights, returned)
#     391
#     392     if weights is None:
# --> 393         avg = a.mean(axis)
#     394         scl = avg.dtype.type(a.size/avg.size)
#     395     else:
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\numpy\core\_methods.py in _mean(a, axis, dtype, out, keepdims)
#     151     ret = umr_sum(arr, axis, dtype, out, keepdims)
#     152     if isinstance(ret, mu.ndarray):
# --> 153         ret = um.true_divide(
#     154                 ret, rcount, out=ret, casting='unsafe', subok=False)
#     155         if is_float16_result and out is None:
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
