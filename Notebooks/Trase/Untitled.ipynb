# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot

# %%
#Form: df = pd.read_csv("data.txt", sep="\t")

df_reviews = pd.read_csv("../../zippedData/rt.reviews.tsv.gz", sep="\t",encoding ="latin")

# %%
df_reviews
# Out:
#          id                                             review rating   fresh  \
# 0         3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1         3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2         3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3         3  Continuing along a line introduced in last yea...    NaN   fresh
# 4         3             ... a perverse twist on neorealism...     NaN   fresh
# ...     ...                                                ...    ...     ...
# 54427  2000  The real charm of this trifle is the deadpan c...    NaN   fresh
# 54428  2000                                                NaN    1/5  rotten
# 54429  2000                                                NaN    2/5  rotten
# 54430  2000                                                NaN  2.5/5  rotten
# 54431  2000                                                NaN    3/5   fresh
#
# ...

# %%
df_reviews.columns
# Out:
# Index(['id', 'review', 'rating', 'fresh', 'critic', 'top_critic', 'publisher',
#        'date'],
#       dtype='object')

# %%
df_reviews['rating'].value_counts()
# Out:
# 3/5      4327
# 4/5      3672
# 3/4      3577
# 2/5      3160
# 2/4      2712
#          ...
# 5.2         1
# 5/4         1
# 7.7         1
# 2.6/5       1
# 4.2/5       1
# Name: rating, Length: 186, dtype: int64

# %%
df_reviews['critic'].value_counts()
# Out:
# Emanuel Levy          595
# Roger Ebert           461
# Dennis Schwartz       413
# Nell Minow            372
# James Berardinelli    348
#                      ...
# Raju Mudhar             1
# Scott Beggs             1
# Moira Walsh             1
# Dave McCoy              1
# Daniel Goodwin          1
# Name: critic, Length: 3496, dtype: int64

# %%
df_reviews['top_critic'].value_counts()
# Out:
# 0    41336
# 1    13096
# Name: top_critic, dtype: int64

# %%
df_reviews['publisher'].value_counts()
# Out:
# eFilmCritic.com          673
# EmanuelLevy.Com          591
# New York Times           590
# Washington Post          565
# Entertainment Weekly     541
#                         ...
# Glue Magazine              1
# Cloture Club               1
# Organica News              1
# Time to Play Magazine      1
# bibloi.com                 1
# Name: publisher, Length: 1281, dtype: int64

# %%
#df['two'].between(-0.5, 0.5, inclusive=False)

#df_reviews['rating'].between(0,5, inclusive=False)

(0 <= df_reviews['rating']) & (df_reviews['rating'] <=5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-476a67425526> in <module>
#       3 #df_reviews['rating'].between(0,5, inclusive=False)
#       4
# ----> 5 (0 <= df_reviews['rating']) & (df_reviews['rating'] <=5)
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\ops\__init__.py in wrapper(self, other)
#     368         rvalues = extract_array(other, extract_numpy=True)
#     369
# --> 370         res_values = comparison_op(lvalues, rvalues, op)
#     371
#     372         return self._construct_result(res_values, name=res_name)
#
# ...

# %%
df_reviews.select_dtypes(include=['number'])
# Out:
#          id  top_critic
# 0         3           0
# 1         3           0
# 2         3           0
# 3         3           0
# 4         3           0
# ...     ...         ...
# 54427  2000           1
# 54428  2000           0
# 54429  2000           0
# 54430  2000           0
# 54431  2000           0
#
# [54432 rows x 2 columns]

# %%
df_reviews.select_dtypes(include=['object'])
# Out:
#                                                   review rating   fresh  \
# 0      A distinctly gallows take on contemporary fina...    3/5   fresh
# 1      It's an allegory in search of a meaning that n...    NaN  rotten
# 2      ... life lived in a bubble in financial dealin...    NaN   fresh
# 3      Continuing along a line introduced in last yea...    NaN   fresh
# 4                 ... a perverse twist on neorealism...     NaN   fresh
# ...                                                  ...    ...     ...
# 54427  The real charm of this trifle is the deadpan c...    NaN   fresh
# 54428                                                NaN    1/5  rotten
# 54429                                                NaN    2/5  rotten
# 54430                                                NaN  2.5/5  rotten
# 54431                                                NaN    3/5   fresh
#
#                   critic         publisher                date
# ...

# %%
df_reviews_ratings = df_reviews[df_reviews[['rating']].notnull().all(1)]
#df[df[['this_column']].notnull().all(1)]
df_reviews_ratings
# Out:
#          id                                             review rating   fresh  \
# 0         3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 6         3  Quickly grows repetitive and tiresome, meander...      C  rotten
# 7         3  Cronenberg is not a director to be daunted by ...    2/5  rotten
# 11        3  While not one of Cronenberg's stronger films, ...     B-   fresh
# 12        3  Robert Pattinson works mighty hard to make Cos...    2/4  rotten
# ...     ...                                                ...    ...     ...
# 54424  2000  Dawdles and drags when it should pop; it doesn...  1.5/5  rotten
# 54428  2000                                                NaN    1/5  rotten
# 54429  2000                                                NaN    2/5  rotten
# 54430  2000                                                NaN  2.5/5  rotten
# 54431  2000                                                NaN    3/5   fresh
#
# ...

# %%
#df_reviews_ratings = df_reviews_ratings[df_reviews_ratings[['']]]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-9f8e9e97bc7f> in <module>
# ----> 1 df_reviews = df_reviews.fillna(0)
#
# AttributeError: 'function' object has no attribute 'fillna'

# %%
df_reviews_ratings.notnull().sum()
# Out:
# id            40915
# review        35379
# rating        40915
# fresh         40915
# critic        38935
# top_critic    40915
# publisher     40688
# date          40915
# dtype: int64
